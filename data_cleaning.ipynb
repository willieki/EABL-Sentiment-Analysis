# %%
import nltk
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from  nltk import FreqDist
from nltk.stem.wordnet import WordNetLemmatizer
import re
from sklearn. feature_extraction. text import CountVectorizer,TfidfVectorizer,TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import make_pipeline

import string
# %matplotlib inline

# %%
df1=pd.read_csv('guinsess-tweeter.csv')
df1.head(15)
# Out:
#     Unnamed: 0                                               data  \
# 0            0  https://twitter.com/mathiasaserbire/status/174...
# 1            1  https://twitter.com/icemone81009479/status/174...
# 2            2  https://twitter.com/scenttokyo/status/17453693...
# 3            3  https://twitter.com/eVisitorGuide/status/17453...
# 4            4  https://twitter.com/shocked_daily/status/17453...
# 5            5  https://twitter.com/FlyerTalkerinA2/status/174...
# 6            6  https://twitter.com/eVisitorGuide/status/17452...
# 7            7  https://twitter.com/sputnik_afrique/status/174...
# 8            8  https://twitter.com/sputnik_afrique/status/174...
# 9            9  https://twitter.com/A_Little_Luney/status/1745...
# 10          10  https://twitter.com/SeefinishPublyk/status/174...
# 11          11  https://twitter.com/momentomori1962/status/174...
# 12          12  https://twitter.com/MichaelEhline/status/17452...
# ...

# %%
print(df1.shape)
print(df1.info)
# Out:
# (602, 5)
# <bound method DataFrame.info of                                                   data  \
# 0    https://twitter.com/mathiasaserbire/status/174...
# 1    https://twitter.com/icemone81009479/status/174...
# 2    https://twitter.com/scenttokyo/status/17453693...
# 3    https://twitter.com/eVisitorGuide/status/17453...
# 4    https://twitter.com/shocked_daily/status/17453...
# ..                                                 ...
# 597  https://twitter.com/sabasmendivil/status/17371...
# 598  https://twitter.com/radiotrek/status/173718052...
# 599  https://twitter.com/newdigitalstech/status/173...
# 600  https://twitter.com/WSportsAlliance/status/173...
# 601  https://twitter.com/OlcaytoCengiz/status/17371...
#
#                                                   text  \
# 0    Ghanaian Chef Faila ends world record cook-a-t...
# 1    #Guinness I been sitting on top of my fears on...
# 2    #beer #craftbeer #shigakogenbeer #minohbeer #d...
# ...

# %%
df1 = df1.drop(df1.columns[0], axis=1)
df1.head
# Out:
# <bound method NDFrame.head of                                                   data  \
# 0    https://twitter.com/mathiasaserbire/status/174...
# 1    https://twitter.com/icemone81009479/status/174...
# 2    https://twitter.com/scenttokyo/status/17453693...
# 3    https://twitter.com/eVisitorGuide/status/17453...
# 4    https://twitter.com/shocked_daily/status/17453...
# ..                                                 ...
# 597  https://twitter.com/sabasmendivil/status/17371...
# 598  https://twitter.com/radiotrek/status/173718052...
# 599  https://twitter.com/newdigitalstech/status/173...
# 600  https://twitter.com/WSportsAlliance/status/173...
# 601  https://twitter.com/OlcaytoCengiz/status/17371...
#
#                                                   text  \
# 0    Ghanaian Chef Faila ends world record cook-a-t...
# 1    #Guinness I been sitting on top of my fears on...
# 2    #beer #craftbeer #shigakogenbeer #minohbeer #d...
# ...

# %%
#Checking if the dataset has any null values for every column.
print("The sum of null values per columns are:")
print(df1.isna().sum())

#Checking for duplicates
print("The data has the following duplicates")
duplicates = df1.duplicated()
print(duplicates.sum())
# Out:
# The sum of null values per columns are:
# data         0
# text         0
# stats        0
# links        0
# sentiment    0
# dtype: int64
# The data has the following duplicates
# 0

# %%
# Removing hashtags,special characters and mentions
#We are going to use a regex tokenizer
from nltk.tokenize import RegexpTokenizer

token_pattern =r'(@\S+|http\S+|[^a-zA-Z\s])'

tokenizer = RegexpTokenizer(basic_token_pattern)

df1["text_tokenized"] = df1["text"].apply(tokenizer.tokenize)

# Displaying the  full tokenized text
df1.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# ...

# %%
#Setting the tokenized text into lower case:
df1['text_tokenized'] = df1['text_tokenized'].apply(lambda x: word_tokenize(x.lower()))
df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-a725aa03ecae> in <module>
#       1 #Setting the tokenized text into lower case:
# ----> 2 df1['text_tokenized'] = df1['text_tokenized'].apply(lambda x: word_tokenize(x.lower()))
#       3 df1
#       4
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-a725aa03ecae> in <lambda>(x)
#       1 #Setting the tokenized text into lower case:
# ...
