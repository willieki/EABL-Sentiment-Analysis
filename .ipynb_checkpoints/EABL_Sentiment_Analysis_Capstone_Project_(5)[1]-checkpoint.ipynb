# %% [markdown]
# # Data-Driven Brand Mastery: EABL's Social Analytics

# %% [markdown]
# ## Business Overview
# Media for brand monitoring to enhance brand perception and customer engagement.
# East African Breweries Limited (EABL) is a leading Fast-Moving Consumer Goods (FMCG) company operating in the beverage industry.
# EABL's market footprint extends across East Africa, with a significant presence in countries such as Kenya, Uganda, Tanzania, Rwanda, and South Sudan.
# With a diverse portfolio of brands such as Tusker Lager, Pilsner Lager, WhiteCap Lager,  Johnnie Walker, Smirnoff, Gilbey's Gin, Richot Brandy, Bond 7 Whiskey and Baileys Irish Cream.
# As part of its strategic approach, EABL is keen on leveraging social
#
# Executive Summary
#
# In the rapidly evolving landscape of social media, businesses are increasingly recognizing the significance of understanding public sentiment towards their brand, products, or industry. Sentiment analysis, particularly using Twitter data, offers a valuable tool for companies to gain actionable insights, enhance customer experience, and make informed business decisions.

# %% [markdown]
# ##  Problem Statement
# EABL recognizes the need to closely monitor and understand the sentiments expressed on social media platforms regarding its brands, products, and marketing initiatives. The company aims to address the following challenges:
#
# #### 1. Brand Perception and Engagement:
#
# The current state of public sentiment towards EABL on social media is not well-understood, and the company lacks insights to proactively manage and improve its brand perception.
#
# #### 2. Marketing Campaign Effectiveness:
#
# EABL needs to evaluate the impact of its marketing campaigns and promotions on social media to optimize strategies and refine future campaigns.
#
# #### 3. Customer Feedback Analysis:
#
# There is a lack of systematic analysis of customer feedback related to product quality, packaging, pricing, and overall satisfaction. EABL aims to utilize this feedback for continuous product improvement and innovation.

# %% [markdown]
# ## Objectives
#
# ### Main Objectives
#
# #### Enhance Brand Perception and Customer Engagement:
#
# The main objective of our project is to monitor and analyze social media conversations to understand public sentiment towards EABL brands.
# Identifying areas for improvement and take proactive measures to enhance overall brand perception.
#
# ### Specific Objectives
#
#
# -To analyze sentiments expressed by consumers regarding EABL products or and brand image.
#
# -To categorize sentiments as positive, negative, or neutral to derive actionable insights.
#
# -To establish the brand that is highly mentioned in social media discussions.
#
# -To establish the most frequently used words by customers to express their sentiments regarding the EABL brands.
#
# Specifying the research questions:
#
# -What are the sentiments expressed by customers regarding EABL products and branch image?
#
# -What categories of sentiments does the discussions fall into?
#
# -Which are the most frequently used words by customers to express their sentiments regarding the EABL brands?
#
# -Which brand is highly mentioned by customers in the social media platforms?

# %% [markdown]
# ###  Success Criteria
#
# The success of this project will be measured by:
#
# 1. A notable improvement in overall brand sentiment scores over a defined period.
#
# 2. Positive shifts in sentiment during and after key marketing campaigns.
#
# 3. Tangible product improvements based on customer feedback.
#
# 4. Enhanced online visibility and engagement compared to competitors.

# %% [markdown]
# ## Stakeholders
#
# #### 1. Marketing Team:
#
# Benefit from insights to optimize marketing strategies and refine campaigns.
#
# #### 2. Product Development Team:
#
# Utilize feedback for continuous product improvement and innovation.
#
# #### 3. Executive Leadership:
#
# Receive regular reports on brand health and public perception for strategic decision-making.

# %% [markdown]
# ## Data Understanding
#
# #### 1. Brand Mentions:
#
# Social media posts, comments, and mentions related to EABL and its brands.
#
# Data sources: Twitter, Facebook, Instagram (Likes, shares, comments, EABL relevant hashtags.)

# %% [markdown]
# ## Product Feedback:
# Comments and discussions regarding specific EABL products.
#
# #### Data sources:
# Social media platforms, review sites, online forums.
#
# Data on taste, packaging, pricing, and overall satisfaction.
#
# #### Campaign Reactions:
# Public reactions to EABL's marketing campaigns and promotions.
#
# Data sources: Social media platforms.
#
# #### Event Participation:
# Social media mentions related to EABL-sponsored events and promotions.
#
# #### Customer Service Interactions:
# Social media interactions with EABL's official customer service handles.

# %% [markdown]
# ## Importing Libraries

# %%
import re
import string
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  #plotting statistical graphs
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
import squarify
from collections import Counter

# Load the Text Cleaning Package
import neattext.functions as nfx

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator ##is a data visualization technique used
#for representing text data in which the size of each word indicates its frequency

from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix,roc_auc_score,classification_report
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.linear_model import RidgeClassifier,SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB


import nltk
from nltk.corpus import stopwords

from tqdm import tqdm ##new progress bars repeatedly
import os
import nltk ##building Python programs to work with human language data
#import spacy #for training the NER model tokenize words
#import random
#from spacy.util import compounding
#from spacy.util import minibatch


pd.set_option('max_colwidth', 400)
pd.set_option('use_mathjax', False)


import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Importing Datasets

# %%
# reading the datasets
Eabl_mentions = pd.read_csv("FinalMentions.CSV")
Eabl_hashtags = pd.read_csv("FinalHashtags.CSV")
Eabl_brands = pd.read_csv("eablProducts.csv")
Google_news = pd.read_csv('FinalGoogleNews.csv')
Chrome_Gin = pd.read_csv("ChromeGin.CSV")

# %% [markdown]
# ##### MERGING DATAFRAMES

# %%
# Combining  the DataFrames vertically to form one df
combined_df = pd.concat([Eabl_mentions, Eabl_hashtags, Eabl_brands, Chrome_Gin], ignore_index=True)
combined_df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                                                                                                                      cleaned_text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                            drilling water at kenneth matiba hospital makenji kandara  gatanga near kenol  kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 4                                                                                                                                                                                                                                                             NaN
#
#   sentiment                       stats  comments  retweets  quotes  likes
# 0  Negative   Jan 7, 2024 · 4:59 AM UTC        14        40       1    157
# 1  Positive   Jan 9, 2024 · 5:13 PM UTC        18        29       1    194
# 2   Neutral   Jan 9, 2024 · 1:45 PM UTC        33       122       2    537
# 3   Neutral  Jan 10, 2024 · 2:43 PM UTC         0         0       0      0
# 4   Neutral  Jan 10, 2024 · 2:39 PM UTC         0         0       0      1

# %%
combined_df.to_csv("CombinedFinal.csv")

# %% [markdown]
# ## 1. DATA CLEANING

# %%
print(f"Our Final Combined data has {combined_df.shape[0]} rows & {combined_df.shape[1]} columns.")
# Out:
# Our Final Combined data has 125218 rows & 8 columns.

# %%
#dropping the Unnamed: 0 column
combined_df = combined_df.drop('Unnamed: 0',axis=1)
combined_df.head(5)
# Out:
#                                                                                                                                                                                                                                                      cleaned_text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                            drilling water at kenneth matiba hospital makenji kandara  gatanga near kenol  kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 4                                                                                                                                                                                                                                                             NaN
#
#   sentiment                       stats  comments  retweets  quotes  likes
# 0  Negative   Jan 7, 2024 · 4:59 AM UTC        14        40       1    157
# 1  Positive   Jan 9, 2024 · 5:13 PM UTC        18        29       1    194
# 2   Neutral   Jan 9, 2024 · 1:45 PM UTC        33       122       2    537
# 3   Neutral  Jan 10, 2024 · 2:43 PM UTC         0         0       0      0
# 4   Neutral  Jan 10, 2024 · 2:39 PM UTC         0         0       0      1

# %%
combined_df.columns
# Out:
# Index(['cleaned_text', 'sentiment', 'stats', 'comments', 'retweets', 'quotes',
#        'likes'],
#       dtype='object')

# %% [markdown]
# ##### 1. Missing values

# %%
# Checking for missing values in each column
missing_values = combined_df.isna().sum()

for column, count in missing_values.items():
    if count > 0:
        print(f"The {column} column has {count} missing values")
# Out:
# The cleaned_text column has 4724 missing values
# The sentiment column has 4 missing values
# The stats column has 2 missing values

# %%
# Calculating percentage of missing values in each column
missing_percentage = combined_df.isna().mean() * 100

missing_percentage = missing_percentage[missing_percentage > 0]

# A DataFrame with columns and percentage of missing values
missing_table = pd.DataFrame({
    'Columns': missing_percentage.index,
    '% of Missing Values': missing_percentage.values
})
print("Percentage of Missing Values")
missing_table
# Out:
# Percentage of Missing Values
#         Columns  % of Missing Values
# 0  cleaned_text             3.772621
# 1     sentiment             0.003194
# 2         stats             0.001597

# %%
# Drop rows with NaN values in the 'cleaned_text', 'sentiment','stats columns
combined_df = combined_df.dropna(subset=['cleaned_text','sentiment','stats'])
combined_df.shape
# Out:
# (120490, 7)

# %% [markdown]
# #####  2. Duplicates

# %%
# checking for dupliacated rows in the df
duplicated_rows = combined_df.duplicated().sum()
print(f'The DataFrame has {duplicated_rows} duplicated rows.')
# Out:
# The DataFrame has 54707 duplicated rows.

# %%
# Calculate the percentage of missing values for each column
missing_percentages1 = (combined_df.isnull().sum() / len(combined_df)) * 100

# Print the result
print("Percentage of missing values in each column:")
print(missing_percentages1)
# Out:
# Percentage of missing values in each column:
# cleaned_text    0.0
# sentiment       0.0
# stats           0.0
# comments        0.0
# retweets        0.0
# quotes          0.0
# likes           0.0
# dtype: float64

# %%
#dropping all the duplicates
combined_df = combined_df.drop_duplicates()

# %%
duplicated_rows = combined_df.duplicated().sum()
print(f'The DataFrame has {duplicated_rows} duplicated rows.')
# Out:
# The DataFrame has 0 duplicated rows.

# %% [markdown]
# #####  3. Correcting Data Types

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65783 entries, 0 to 125217
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cleaned_text  65783 non-null  object
#  1   sentiment     65783 non-null  object
#  2   stats         65783 non-null  object
#  3   comments      65783 non-null  int64
#  4   retweets      65783 non-null  int64
#  5   quotes        65783 non-null  int64
#  6   likes         65783 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 4.0+ MB

# %% [markdown]
# #####  4. Outliers

# %%
# style for seaborn
sns.set(style="whitegrid")

# columns to check for outliers
columns_to_check = ['comments', 'retweets', 'quotes', 'likes']

# subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

# Flatten the axes for easy iteration
axes = axes.flatten()

# Plot box plots for each column
for i, column in enumerate(columns_to_check):
    sns.boxplot(x=combined_df[column], ax=axes[i])
    axes[i].set_title(f'Box Plot - {column}')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 5. Removing Uncessary Text

# %%
def clean_text(text):
    # Removing any unnecessary characters, symbols, or special characters
    cleaned_text = ' '.join(e for e in str(text).split() if (e.isalnum() or e.isspace()))
    # Converting all the text to lowercase
    cleaned_text = cleaned_text.lower()
    # Removing extra whitespaces
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# Applying the cleaning function to the 'cleaned_text' column
combined_df['cleaned_text'] = combined_df['cleaned_text'].apply(clean_text)

# %% [markdown]
# ## 2. FEATURE ENGINEERING

# %%
combined_df.head(5)
# Out:
#                                                                                                                                                                                                                                                      cleaned_text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#   sentiment                        stats  comments  retweets  quotes  likes
# 0  Negative    Jan 7, 2024 · 4:59 AM UTC        14        40       1    157
# 1  Positive    Jan 9, 2024 · 5:13 PM UTC        18        29       1    194
# 2   Neutral    Jan 9, 2024 · 1:45 PM UTC        33       122       2    537
# 3   Neutral   Jan 10, 2024 · 2:43 PM UTC         0         0       0      0
# 6   Neutral  Jan 10, 2024 · 10:12 AM UTC         1         0       0      0

# %% [markdown]
# ##### 1. Length of the text

# %%
# Calculating  the number of words in the 'cleaned_text' column
combined_df['text_length_words'] = combined_df['cleaned_text'].apply(lambda x: len(str(x).split()))

combined_df[['cleaned_text', 'text_length_words']].head()
# Out:
#                                                                                                                                                                                                                                                      cleaned_text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#    text_length_words
# 0                 45
# 1                 28
# 2                  9
# 3                  9
# 6                 19

# %%
print(f"The Maximum number of words is {combined_df['text_length_words'].max()} & The Minimum number of words is {combined_df['text_length_words'].min()}")
# Out:
# The Maximum number of words is 879 & The Minimum number of words is 0

# %% [markdown]
# ##### 2. Datetime Features

# %%
# Converting 'stats' column to datetime format
combined_df['stats'] = pd.to_datetime(combined_df['stats'], format='%b %d, %Y · %I:%M %p UTC', errors='coerce')

# Extracting datetime features
combined_df['day'] = combined_df['stats'].dt.day
combined_df['month'] = combined_df['stats'].dt.month
combined_df['year'] = combined_df['stats'].dt.year
combined_df['hour'] = combined_df['stats'].dt.hour
combined_df['day_of_week'] = combined_df['stats'].dt.dayofweek

combined_df[['stats', 'day', 'month', 'year', 'hour','day_of_week']].head()
# Out:
#                 stats   day  month    year  hour  day_of_week
# 0 2024-01-07 04:59:00   7.0    1.0  2024.0   4.0          6.0
# 1 2024-01-09 17:13:00   9.0    1.0  2024.0  17.0          1.0
# 2 2024-01-09 13:45:00   9.0    1.0  2024.0  13.0          1.0
# 3 2024-01-10 14:43:00  10.0    1.0  2024.0  14.0          2.0
# 6 2024-01-10 10:12:00  10.0    1.0  2024.0  10.0          2.0

# %%
# Converting 'day_of_week' to text
day_of_week_mapping = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
combined_df['day_of_week_text'] = combined_df['day_of_week'].map(day_of_week_mapping)

# Converting 'month' to text
month_mapping = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}
combined_df['month_text'] = combined_df['month'].map(month_mapping)

combined_df[['stats', 'day', 'month', 'year', 'hour','day_of_week_text', 'month_text']].head()
# Out:
#                 stats   day  month    year  hour day_of_week_text month_text
# 0 2024-01-07 04:59:00   7.0    1.0  2024.0   4.0           Sunday    January
# 1 2024-01-09 17:13:00   9.0    1.0  2024.0  17.0          Tuesday    January
# 2 2024-01-09 13:45:00   9.0    1.0  2024.0  13.0          Tuesday    January
# 3 2024-01-10 14:43:00  10.0    1.0  2024.0  14.0        Wednesday    January
# 6 2024-01-10 10:12:00  10.0    1.0  2024.0  10.0        Wednesday    January

# %% [markdown]
# ##### 3. Total Engagement

# %%
# calculating the total number of engagement in each post
combined_df['total_engagement'] = combined_df['comments'] + combined_df['retweets'] + combined_df['quotes'] + combined_df['likes']

# %%
# # Define the keywords
#keywords = ['Chrome', 'Oktoberfest', 'Gilbeys', 'Tusker',]

# # Create columns for each keyword
#for keyword in keywords:
    #combined_df[f'mentions_{keyword.lower()}'] = combined_df['cleaned_text'].str.contains(keyword, case=False)

# # Convert the boolean values to 1 for True and 0 for False
#for keyword in keywords:
    #combined_df[f'mentions_{keyword.lower()}'] = combined_df[f'mentions_{keyword.lower()}'].astype(int)

# %% [markdown]
# ##### 4. Total Engagement

# %%
# A function to classify weekdays and weekends
def classify_weekday_weekend(day_of_week):
    if day_of_week < 5:  # Monday to Friday (0 to 4)
        return 'Weekday'
    else:  # Saturday and Sunday (5 and 6)
        return 'Weekend'

# Apply the function to create a new 'weekday_or_weekend' column
combined_df['weekday_or_weekend'] = combined_df['day_of_week'].apply(classify_weekday_weekend)

# %%
combined_df.columns
# Out:
# Index(['cleaned_text', 'sentiment', 'stats', 'comments', 'retweets', 'quotes',
#        'likes', 'text_length_words', 'day', 'month', 'year', 'hour',
#        'day_of_week', 'day_of_week_text', 'month_text', 'total_engagement',
#        'weekday_or_weekend'],
#       dtype='object')

# %%
#dropping irrelevant columns
combined_df = combined_df.drop(['stats','day_of_week','month'],axis=1)

# %%
# Renaming the columns
combined_df = combined_df.rename(columns={
    'cleaned_text': 'text',
    'text_length_words': 'length',
    'day': 'day(month)',
    'day_of_week_text': 'day(week)',
    'month_text': 'month',
    'weekday_or_weekend': 'weekday/end'
})

# Display the DataFrame with the renamed columns
combined_df.head()
# Out:
#                                                                                                                                                                                                                                                              text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#   sentiment  comments  retweets  quotes  likes  length  day(month)    year  \
# 0  Negative        14        40       1    157      45         7.0  2024.0
# 1  Positive        18        29       1    194      28         9.0  2024.0
# 2   Neutral        33       122       2    537       9         9.0  2024.0
# 3   Neutral         0         0       0      0       9        10.0  2024.0
# 6   Neutral         1         0       0      0      19        10.0  2024.0
#
#    hour  day(week)    month  total_engagement weekday/end
# 0   4.0     Sunday  January               212     Weekend
# 1  17.0    Tuesday  January               242     Weekday
# 2  13.0    Tuesday  January               694     Weekday
# 3  14.0  Wednesday  January                 0     Weekday
# 6  10.0  Wednesday  January                 1     Weekday

# %%
# !pip install squarify
# !pip install neattext
# !pip install wordcloud
# Out:
# Requirement already satisfied: squarify in c:\users\user\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: neattext in c:\users\user\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: wordcloud in c:\users\user\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Before conducting sentiment analysis, it is imperative to follow these essential steps: eliminating stop words, removing tags, URL links, and other extraneous words, tokenizing the text, and lemmatizing words.

# %%
#clean tweets
#Glance at data
combined_df['text'][:20]
# Out:
# 0                guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                                            drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                               kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                                      i thought eabl products are unwanted around the mountain
# 6                                                                                                                                                      unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
# 8                                                                                                                                                                                       eabl have done the thingexpect changes to prices of white cap guinness and tusker cider
# 10                                                                                                                                                                       talk to eabl mchukuwe tusker fc change the name to tusker meru fc and have them play at kinoru stadium
# 12                                                                                                                                                                                                             and is selling its beer business hustlers turning into dynasties
# 13                                 just thank for the good work benefits to eabl juu hawatakosa sorghum when needed muranga county projects should not have partnerships toeni hio reli iko kwa barabara and we can have to congratulate something that had been there for ages
# 14                                                                                                                                                                                                                    eabl as usual watatumia shady business tactics to compete
# 15                                                                      market share is a thing it would will years before they can be at par with theres also the small matter of the range of products people have different palletes catering to all of them is a tall order
# 16                                                                                                                                                                                                                         na ati cs wa maji alikuwa wa huko na mnategemea eabl
# 17                                                                                                                                                                                            eabl will do what they do best in such scenario remember what they did to tabitha
# 18                                                                                                                                                                                                                                               thanks so much for the mention
# 19                                                                                                                                                                                               296fb im followin u im full blue dem resister please me resisters listd here 2
# 20                                                                                                                                                               what would you say to the claim the fox folks thought hiring blondes was more important than hiring excellence
# 21                                                                                                                                                                                                                                         huwa mnafikiria eabl ni kibanda lmao
# 22                                                                             a beautiful sable island stallion this fall when i visited sable island was curious but unafraid as we walked by me with his family those long tangled windswept manes are so amazing wildhorses
# 23                                              eight days into the new year and flights carrying horses to japan for slaughter have already begun more are planned please send the letter at horseshitca to your mp asking them to support bill c355 koreanair edmontonairport
# 24    this foal mentioned in previous post was put down on jan 6th for a dislocated right front knee the injury was recorded as acute by the blm meaning it was sustained during the roundup as of yesterday 866 wild horses have been captured and the death toll stands at 11
# Name: text, dtype: object

# %% [markdown]
# # Checking for tweet Length Consistency

# %%
combined_df['text'].apply(len).value_counts()
# Out:
# 7       920
# 14      713
# 15      671
# 10      669
# 26      617
#        ...
# 485       1
# 680       1
# 1384      1
# 818       1
# 1214      1
# Name: text, Length: 654, dtype: int64

# %% [markdown]
# This gives an overview of the number of words per tweet. We also notice that some consist of less than five words therefore won't be instrumental in constructing our predictive model.

# %%
sum(combined_df['text'].apply(len) > 5) , sum(combined_df['text'].apply(len) <= 5)
# Out:
# (64260, 1523)

# %% [markdown]
# We note tht there are 64260 tweets with characters greater than 5 and  1523 tweets with characters less than 5 characters.

# %%
print("Shape of the dataset before filtering:")
print(combined_df.shape)
print("*"*40)
combined_df = combined_df[combined_df['text'].apply(len) > 5]
print("Shape of the dataset after filtering:")
print(combined_df.shape)
# Out:
# Shape of the dataset before filtering:
# (65783, 14)
# ****************************************
# Shape of the dataset after filtering:
# (64260, 14)

# %% [markdown]
# # Checking for Duplicates in the dataset

# %%
print(combined_df.duplicated().sum())
# Out:
# 775

# %% [markdown]
# We want to investigate if indeed these are duplicate values.

# %%
# checking if the duolicate values are indeed duplicates
combined_df[combined_df.duplicated(subset=['text'],keep=False)].sort_values(by='text').sample(10)
# Out:
#                                                                                                                                                                                                                                                                       text  \
# 670                                                                                                                                                                                                       eabl shakes up craft beer market with launch of new microbrewery
# 42824                       grab your tickets from the bar in this format buy 1 350ml gilbeys mixed berries on and get 1 ticket buy 1 750ml gilbeys mixed berries on the bar and get 2 tickets buy 2 750ml gilbeys mixed berries on the bar and get squad tickets 5 people
# 1813   i realised that if you drink gilbeys ya events za eabl inakuwanga smoother hata kuliko most high end gins lakini make the mistake of drinking gilbeys ya liquor stores you will be hangovered for a whole week i honestly just buy best gin kama ni ya liquor store
# 63207                                                                                                                                                                                              thank you guntiserbeverages sibebe 2m maluti tusker laurentina whitecap
# 20127                                                                                                                                                                                                                                                           bell lager
# 63475                                                                                                                                                                 tusker preview will the brewers be crowned champions mambolookcomafcleopards mambolookcomlink6135628
# 13070                                                                                                                                                                                                                                                             aya bass
# 42635                                                                                                                                                                                                                                                              gilbeys
# 62114                                                                                                                                                                   homeboyz 11 tusker homeboyz dent brewers title mambokenyacompage11827725 mambokenyacomfootballteam
# 18096                                                                                                                                                                                                                                                           bell lager
#
#       sentiment  comments  retweets  quotes  likes  length  day(month)  \
# 670    Positive         0         0       0      0      11         6.0
# 42824   neutral         0         1       0      1      48        27.0
# 1813   Positive         0         0       0      1      48         5.0
# 63207  positive         0         0       0      0       9        15.0
# 20127   neutral         0         0       0      0       2        11.0
# 63475   neutral         0         0       0      0      10         6.0
# 13070   neutral         1         0       0      0       2         5.0
# 42635   neutral         1         0       0      0       1        29.0
# 62114   neutral         0         0       0      0       9        28.0
# 18096   neutral         0         0       0      0       2        16.0
#
#          year  hour  day(week)      month  total_engagement weekday/end
# 670    2023.0  10.0  Wednesday   December                 0     Weekday
# 42824  2023.0  16.0     Friday    January                 2     Weekday
# 1813   2023.0  13.0   Thursday    October                 1     Weekday
# 63207  2016.0  19.0   Thursday   December                 0     Weekday
# 20127  2023.0   6.0   Saturday   February                 0     Weekend
# 63475  2016.0   5.0     Sunday   November                 0     Weekend
# 13070  2023.0  17.0    Tuesday  September                 1     Weekday
# 42635  2023.0   4.0     Sunday    January                 1     Weekend
# 62114  2017.0   5.0     Monday     August                 0     Weekday
# 18096  2023.0  17.0     Sunday      April                 0     Weekend

# %% [markdown]
# From the output displyed, it is not evident if there are duplicated tweets. We chose to retain the duplicates.

# %% [markdown]
# We will now got to preprocessing procedures which include tokenizing(spliting),stemming and lemmatization which are dependent on the model you choose to use.

# %% [markdown]
# For cleaning our text we are gling to use the NeatText Library. NeatText is a simple NLP package for cleaning textual data and text preprocessing. It offers a variety of features for cleaning unstructured text data, reducing noise (such as special characters and stopwords), and extracting specific information from the text. It can be used via an object-oriented approach or a functional/method-oriented approach, providing flexibility in its usage. The package includes classes such as TextCleaner, TextExtractor, and TextMetrics for different text processing tasks.

# %%
# load the text cleaning packages

import neattext as nt
import neattext.functions as nfx

# Methods and Attributes of the function
dir(nt)
# Out:
# ['AUTOMATED_READ_INDEX',
#  'BTC_ADDRESS_REGEX',
#  'CONTRACTIONS_DICT',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Callable',
#  'Counter',
#  'CreditCard_REGEX',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'FUNCTORS_WORDLIST',
#  'HASTAG_REGEX',
#  'HTML_TAGS_REGEX',
#  'List',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PUNCT_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextCleaner',
#  'TextExtractor',
#  'TextFrame',
#  'TextMetrics',
#  'TextPipeline',
#  'Tuple',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  'ZIP_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'emoji_explainer',
#  'emojify',
#  'explainer',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'functions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'neattext',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'pattern_data',
#  'pipeline',
#  'random',
#  're',
#  'read_txt',
#  'remove_accents',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'unicode_2_emoji',
#  'unicodedata',
#  'word_freq',
#  'word_length_freq']

# %%
# Scaning the Noise
combined_df['text'].apply(lambda x: nt.TextFrame(x).noise_scan()['text_noise'])
# Out:
# 0          5.905512
# 1          3.370787
# 2          8.510638
# 3          7.142857
# 6          0.833333
#             ...
# 125213    10.606061
# 125214    11.718750
# 125215    11.111111
# 125216     0.000000
# 125217     0.000000
# Name: text, Length: 64260, dtype: float64

# %%
# Ensure all entries in 'tweet' column are strings
combined_df['text'] = combined_df['text'].astype(str)

# Now apply the clean_text function
combined_df['clean_text'] = combined_df['text'].apply(lambda x: nfx.clean_text(x, puncts=False, stopwords=False))

# %%
combined_df[['text', 'clean_text']].head()
# Out:
#                                                                                                                                                                                                                                                              text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                                                                                                                        clean_text
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana

# %% [markdown]
# # Special Characters

# %%
# Remove special characters

combined_df['clean_text'] = combined_df['clean_text'].apply(nfx.remove_special_characters)

combined_df[['text', 'clean_text']].sample(5)
# Out:
#                                                                                                                                                                                                                                              text  \
# 24571                                                                                                                                                                                                                          mcc representating
# 21252  do expired soldout slogans have an impact on business performance success stories movitbell lager 90sbell lager had a tagline omunyi wa bell tabulawhen millennials over streets 2 them having a belly was newzugdoexpiredsoldout ugandans
# 42825                              buy 1 350ml gilbeys mixed berries on and get 1 ticket buy 1 750ml gilbeys mixed berries on the bar and get 2 tickets buy 2 750ml gilbeys mixed berries on the bar and get squad tickets 5 people opengoodtimes
# 59495                            perumal elephant giant beast kerala elephants tusk king kerala pet elephant giant petlover majestic king aana pampady elephant pampadyrajan pooram petlover petshow animals tusker tuskers natgeo petbath aanapr
# 36470                                                                                      enjoy gilbeys dry gin at just ksh 999 and save a cool ksh 551 on every 750ml bottle its time to drink responsibly and shop smartly quickmartgilbeys999
#
#                                                                                                                                                                                                                                        clean_text
# 24571                                                                                                                                                                                                                          mcc representating
# 21252  do expired soldout slogans have an impact on business performance success stories movitbell lager 90sbell lager had a tagline omunyi wa bell tabulawhen millennials over streets 2 them having a belly was newzugdoexpiredsoldout ugandans
# 42825                              buy 1 350ml gilbeys mixed berries on and get 1 ticket buy 1 750ml gilbeys mixed berries on the bar and get 2 tickets buy 2 750ml gilbeys mixed berries on the bar and get squad tickets 5 people opengoodtimes
# 59495                            perumal elephant giant beast kerala elephants tusk king kerala pet elephant giant petlover majestic king aana pampady elephant pampadyrajan pooram petlover petshow animals tusker tuskers natgeo petbath aanapr
# 36470                                                                                      enjoy gilbeys dry gin at just ksh 999 and save a cool ksh 551 on every 750ml bottle its time to drink responsibly and shop smartly quickmartgilbeys999

# %%
# Remove whitespaces
combined_df['clean_text'] = combined_df['clean_text'].apply(nfx.remove_multiple_spaces)

combined_df[['text', 'clean_text']].head()
# Out:
#                                                                                                                                                                                                                                                              text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                                                                                                                        clean_text
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana

# %%
# Remove emojis
combined_df['clean_text'] = combined_df['clean_text'].apply(nfx.remove_emojis)

combined_df[['text', 'clean_text']].sample(5)
# Out:
#                                                                                                                                                                        text  \
# 37900                                                                                                                    if you are poor unakunywa gilbeys kucelebrate nini
# 26268                                                                                                                     served with a side of grasshoppers and bell lager
# 30844                                                        even if you are just going to your living room grab that anti mpolaenjoyments itsabelllagerthing on ntvmixshow
# 3208   sasha obama breaking news jkia john kiriamiti eabl eastleigh king charles iii usd 5000 whats on your feet today 39 40 41 42 43 44 45 46 budgeting at 4950 0721207052
# 19222                                                                                                                                                 thank you please vote
#
#                                                                                                                                                                  clean_text
# 37900                                                                                                                    if you are poor unakunywa gilbeys kucelebrate nini
# 26268                                                                                                                     served with a side of grasshoppers and bell lager
# 30844                                                        even if you are just going to your living room grab that anti mpolaenjoyments itsabelllagerthing on ntvmixshow
# 3208   sasha obama breaking news jkia john kiriamiti eabl eastleigh king charles iii usd 5000 whats on your feet today 39 40 41 42 43 44 45 46 budgeting at 4950 0721207052
# 19222                                                                                                                                                 thank you please vote

# %% [markdown]
# # Contractions
#
# Contractions in a tweet refer to shortened forms of words or phrases that are created by combining two words and replacing one or more letters with an apostrophe. Contractions are commonly used in informal writing, including tweets, to save space and make the text more conversational.

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in c:\users\user\anaconda3\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\user\anaconda3\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\user\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\user\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (2.0.0)

# %%
import contractions

# Apply the contractions.fix function to the clean_tweet column
combined_df['clean_text'] = combined_df['clean_text'].apply(contractions.fix)

combined_df[['text', 'clean_text']].head()
# Out:
#                                                                                                                                                                                                                                                              text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                                                                                                                          clean_text
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara could not be there
# 1                                                                                drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                   kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                          i thought eabl products are unwanted around the mountain
# 6                                                                                                                                          unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana

# %%
# Extract stopwords
combined_df['clean_text'].apply(lambda x: nt.TextExtractor(x).extract_stopwords())
# Out:
# 0         [do, you, was, from, they, about, what, to, of, the, same, if, of, could, not, be, there]
# 1                                                                       [at, a, by, after, the, on]
# 2                                                                               [it, is, over, for]
# 3                                                                             [i, are, around, the]
# 6                                                                                               [a]
#                                                     ...
# 125213                                                        [should, not, be, to, under, the, of]
# 125214         [these, to, be, in, the, front, as, the, of, the, in, the, back, they, have, to, be]
# 125215                                                                           [get, a, at, just]
# 125216                                                                                           []
# 125217                                                                                           []
# Name: clean_text, Length: 64260, dtype: object

# %%
# Removing the stop words

combined_df['clean_text'] = combined_df['clean_text'].apply(nfx.remove_stopwords)

combined_df[['text', 'clean_text']].head()
# Out:
#                                                                                                                                                                                                                                                              text  \
# 0  guys do you remember shaffie weru dj joe mfalmeneville musya was fired from home boys radio coz they warned ladies about what happened to starlet wahu pastor kanyari sizeabl got mad coz of the same if ladies listened likes of john matara couldnt be there
# 1                                                                              drilling water at kenneth matiba hospital makenji kandara gatanga near kenol kabati towns a free donation by eabl after the muranga county eabl partnership on sorghum thanks eabl
# 2                                                                                                                                                                                                                 kenyans wakitambua hii beer it is over for eabl
# 3                                                                                                                                                                                                        i thought eabl products are unwanted around the mountain
# 6                                                                                                                                        unajua sai amafanya eabl anaweza tupea a years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                                                  clean_text
# 0  guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                             drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                          kenyans wakitambua hii beer eabl
# 3                                                                                                                                                   thought eabl products unwanted mountain
# 6                                                                    unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana

# %%
# Noise Scan after text cleaning
combined_df['clean_text'].apply(lambda x: nt.TextFrame(x).noise_scan()['text_noise'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 6         0
#          ..
# 125213    0
# 125214    0
# 125215    0
# 125216    0
# 125217    0
# Name: clean_text, Length: 64260, dtype: int64

# %% [markdown]
# # Language Processing (Clean Text)

# %% [markdown]
# This involves Tokenization, Stemming / Lemmatization, Parts of Speech Tagging and Calculating Sentiment Based on Polarity & Subjectivity.

# %%
test_sample = combined_df['clean_text'].loc[500]

test_sample
# Out:
# 'eabl paid courtesy council governors discuss sector trade counties concerns hinder overall safety revenue performance continue engage aim adding value objectives'

# %%
from nltk.tokenize import RegexpTokenizer

basic_token_pattern = r"(?u)\b\w\w+\b"

tokenizer = RegexpTokenizer(basic_token_pattern)

tokenizer.tokenize(test_sample)
# Out:
# ['eabl',
#  'paid',
#  'courtesy',
#  'council',
#  'governors',
#  'discuss',
#  'sector',
#  'trade',
#  'counties',
#  'concerns',
#  'hinder',
#  'overall',
#  'safety',
#  'revenue',
#  'performance',
#  'continue',
#  'engage',
#  'aim',
#  'adding',
#  'value',
#  'objectives']

# %%
# Tokenise the clean_tweet column
combined_df['preprocessed_text'] = combined_df['clean_text'].apply(lambda x: tokenizer.tokenize(x))

# %%
combined_df.iloc[100]["preprocessed_text"][:20]
# Out:
# ['soon',
#  'start',
#  'selling',
#  'water',
#  'instead',
#  'bear',
#  'new',
#  'lager',
#  'flat',
#  'hell',
#  'unakunywa',
#  'na',
#  'haishiki',
#  'hata']

# %%
combined_df[['clean_text', 'preprocessed_text']].iloc[100]
# Out:
# clean_text                          soon start selling water instead bear new lager flat hell unakunywa na haishiki hata
# preprocessed_text    [soon, start, selling, water, instead, bear, new, lager, flat, hell, unakunywa, na, haishiki, hata]
# Name: 111, dtype: object

# %% [markdown]
# # Lemmatization
# Lemmatization is a linguistic processing technique that involves reducing words to their base or root form, known as the lemma.The purpose of lemmatization is to standardize and simplify words, considering different inflections or variations of a word as a single base form. This aids in tasks such as text analysis, natural language processing, and information retrieval by treating related forms of a word as identical

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Define a function to lemmatise the tokens
def lemmatise_tokens(tokens):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

# %%
# Lemmatise the tokens
combined_df['lemma_preprocessed_text'] = combined_df['preprocessed_text'].apply(lambda x: lemmatise_tokens(x))
combined_df[['clean_text', 'lemma_preprocessed_text']].iloc[400]
# Out:
# clean_text                                   tyrece lacey daniel nwauzu return eabl players week regular stars turned big way teams game week eabl campaign week nines players week
# lemma_preprocessed_text    [tyrece, lacey, daniel, nwauzu, return, eabl, player, week, regular, star, turned, big, way, team, game, week, eabl, campaign, week, nine, player, week]
# Name: 450, dtype: object

# %%
# Defining a function to stem the tokens
def stem_tokens(tokens):
    stemmer = nltk.stem.PorterStemmer()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens
# Stemming the tokens
combined_df['stemma_preprocessed_text'] = combined_df['preprocessed_text'].apply(lambda x: stem_tokens(x))

combined_df[['clean_text', 'stemma_preprocessed_text']].iloc[800]
# Out:
# clean_text                                  walai sijapitia site yao hujua wao ni senator keg solo eabl ndio nimepitia products zao utaona drink fraction
# stemma_preprocessed_text    [walai, sijapitia, site, yao, hujua, wao, ni, senat, keg, solo, eabl, ndio, nimepitia, product, zao, utaona, drink, fraction]
# Name: 864, dtype: object

# %% [markdown]
# # Calculatition of Sentiments Based on Polarity & Subjectivity
# TextBlob is a Python library used for processing textual data, including sentiment analysis. It uses natural language processing (NLP) and the Natural Language Toolkit (NLTK) to achieve this task. When a sentence is passed into TextBlob, it returns two outputs: polarity and subjectivity. The polarity score is a float within the range [-1, 1], where -1 indicates a negative sentiment and 1 indicates a positive sentiment. The subjectivity score is a float within the range, where 0 is very objective and 1 is very subjective.

# %%
from textblob import TextBlob

# Create a function to get the subjectivity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
  return TextBlob(text).sentiment.polarity

# Create two new columns 'Subjectivity' & 'Polarity'
combined_df['Subjectivity'] = combined_df['clean_text'].apply(getSubjectivity)
combined_df['Polarity'] = combined_df['clean_text'].apply(getPolarity)

# Show the new dataframe with columns 'Subjectivity' & 'Polarity'
combined_df[['clean_text','Subjectivity','Polarity']].head()
# Out:
#                                                                                                                                                                                  clean_text  \
# 0  guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                             drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                          kenyans wakitambua hii beer eabl
# 3                                                                                                                                                   thought eabl products unwanted mountain
# 6                                                                    unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#    Subjectivity  Polarity
# 0      1.000000 -0.625000
# 1      0.466667  0.233333
# 2      0.000000  0.000000
# 3      0.000000  0.000000
# 6      0.000000  0.000000

# %%
# Creating a function to compute the negative, positive and nuetral analysis
def getAnalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'
  
combined_df['sentiment'] = combined_df['Polarity'].apply(getAnalysis)

# Showing the dataframe
combined_df[['clean_text','Subjectivity','Polarity','sentiment']].head()
# Out:
#                                                                                                                                                                                  clean_text  \
# 0  guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                             drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                          kenyans wakitambua hii beer eabl
# 3                                                                                                                                                   thought eabl products unwanted mountain
# 6                                                                    unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#    Subjectivity  Polarity sentiment
# 0      1.000000 -0.625000  Negative
# 1      0.466667  0.233333  Positive
# 2      0.000000  0.000000   Neutral
# 3      0.000000  0.000000   Neutral
# 6      0.000000  0.000000   Neutral

# %%
combined_df['sentiment'].value_counts()
# Out:
# Neutral     37427
# Positive    20020
# Negative     6813
# Name: sentiment, dtype: int64

# %%
#previewing our processed text
combined_df['preprocessed_text']
# Out:
# 0         [guys, remember, shaffie, weru, dj, joe, mfalmeneville, musya, fired, home, boys, radio, coz, warned, ladies, happened, starlet, wahu, pastor, kanyari, sizeabl, got, mad, coz, ladies, listened, likes, john, matara]
# 1                                           [drilling, water, kenneth, matiba, hospital, makenji, kandara, gatanga, near, kenol, kabati, towns, free, donation, eabl, muranga, county, eabl, partnership, sorghum, thanks, eabl]
# 2                                                                                                                                                                                         [kenyans, wakitambua, hii, beer, eabl]
# 3                                                                                                                                                                                  [thought, eabl, products, unwanted, mountain]
# 6                                                                                      [unajua, sai, amafanya, eabl, anaweza, tupea, years, supply, ya, balozi, na, singleton, kama, yobra, wewe, unapepeta, tutablockiwa, bana]
#                                                                                                                    ...
# 125213                                                                                                                                                                               [alcohol, sold, people, age, 18, chromegin]
# 125214                                                                                                                                             [drinks, deserve, seat, rest, crew, fit, na, kwa, boot, got, safe, chromegin]
# 125215                                                                                                                                                                                                l, ksh600, chromegin]
# 125216                                                                                                                                                                                                    [enjoyment, chromegin]
# 125217                                                                                                                                     [zinapiga, boomerang, tu, hapa, zikingoja, maji, ichemke, tuanze, sherehe, chromegin]
# Name: preprocessed_text, Length: 64260, dtype: object

# %%
#previewing the processed data
combined_df['lemma_preprocessed_text'] = combined_df['lemma_preprocessed_text'].apply(lambda x: ' '.join(x))

combined_df['stemma_preprocessed_text'] = combined_df['stemma_preprocessed_text'].apply(lambda x: ' '.join(x))

combined_df['preprocessed_text'] = combined_df['preprocessed_text'].apply(lambda x: ' '.join(x))

combined_df['preprocessed_text']
# Out:
# 0         guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                                    drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                                 kenyans wakitambua hii beer eabl
# 3                                                                                                                                                          thought eabl products unwanted mountain
# 6                                                                           unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#                                                                                                     ...
# 125213                                                                                                                                                        alcohol sold people age 18 chromegin
# 125214                                                                                                                            drinks deserve seat rest crew fit na kwa boot got safe chromegin
# 125215                                                                                                                                                                      750ml ksh600 chromegin
# 125216                                                                                                                                                                         enjoyment chromegin
# 125217                                                                                                                  zinapiga boomerang tu hapa zikingoja maji ichemke tuanze sherehe chromegin
# Name: preprocessed_text, Length: 64260, dtype: object

# %%
#checking more information of the processed dataset
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64260 entries, 0 to 125217
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   text                      64260 non-null  object
#  1   sentiment                 64260 non-null  object
#  2   comments                  64260 non-null  int64
#  3   retweets                  64260 non-null  int64
#  4   quotes                    64260 non-null  int64
#  5   likes                     64260 non-null  int64
#  6   length                    64260 non-null  int64
#  7   day(month)                63991 non-null  float64
#  8   year                      63991 non-null  float64
#  9   hour                      63991 non-null  float64
#  10  day(week)                 63991 non-null  object
#  11  month                     63991 non-null  object
#  12  total_engagement          64260 non-null  int64
#  13  weekday/end               64260 non-null  object
#  14  clean_text                64260 non-null  object
#  15  preprocessed_text         64260 non-null  object
#  16  lemma_preprocessed_text   64260 non-null  object
#  17  stemma_preprocessed_text  64260 non-null  object
#  18  Subjectivity              64260 non-null  float64
#  19  Polarity                  64260 non-null  float64
# dtypes: float64(5), int64(6), object(9)
# memory usage: 12.3+ MB

# %%
# save the dataframe to csv using the name 'interim_data.csv' fo the data folder
combined_df.to_csv('Processed_data.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis
# Exploratory Data Analysis involves conducting preliminary examinations of data to unveil hidden patterns, validate hypotheses, and pinpoint anomalies. This method empowers us to extract insights from the data that extend beyond the confines of formal modeling or hypothesis testing, providing a comprehensive understanding of the information at hand.

# %%
Processed_df = pd.read_csv('Processed_data.csv')

Processed_df.sample()
# Out:
#                                                                                         text  \
# 62046  who else is damn sick and tired of watching hunter biden do whatever the hell he want
#
#       sentiment  comments  retweets  quotes  likes  length  day(month)  \
# 62046  Negative      4850     10346     467  59262      17        10.0
#
#          year  hour  day(week)    month  total_engagement weekday/end  \
# 62046  2024.0  15.0  Wednesday  January             74925     Weekday
#
#                                             clean_text  \
# 62046  damn sick tired watching hunter biden hell want
#
#                                      preprocessed_text  \
# 62046  damn sick tired watching hunter biden hell want
#
#                                lemma_preprocessed_text  \
# 62046  damn sick tired watching hunter biden hell want
#
#                           stemma_preprocessed_text  Subjectivity  Polarity
# 62046  damn sick tire watch hunter biden hell want      0.778571 -0.557143

# %%
#checking for shape
Processed_df.shape
# Out:
# (64260, 20)

# %%
#Checking for missing values
Processed_df.isna().sum()
# Out:
# text                          0
# sentiment                     0
# comments                      0
# retweets                      0
# quotes                        0
# likes                         0
# length                        0
# day(month)                  269
# year                        269
# hour                        269
# day(week)                   269
# month                       269
# total_engagement              0
# weekday/end                   0
# clean_text                  224
# preprocessed_text           230
# lemma_preprocessed_text     230
# stemma_preprocessed_text    230
# Subjectivity                  0
# Polarity                      0
# dtype: int64

# %% [markdown]
# We note that we have some missing values in our dataset. We chose to drop them since we won't be losing a good chunk of data.

# %%
# drop the null values
Processed_df.dropna(inplace=True)
Processed_df.isna().sum()
# Out:
# text                        0
# sentiment                   0
# comments                    0
# retweets                    0
# quotes                      0
# likes                       0
# length                      0
# day(month)                  0
# year                        0
# hour                        0
# day(week)                   0
# month                       0
# total_engagement            0
# weekday/end                 0
# clean_text                  0
# preprocessed_text           0
# lemma_preprocessed_text     0
# stemma_preprocessed_text    0
# Subjectivity                0
# Polarity                    0
# dtype: int64

# %%
Processed_df['sentiment'].value_counts()
# Out:
# Neutral     37079
# Positive    19903
# Negative     6779
# Name: sentiment, dtype: int64

# %%
#Distribution of Sentiments
plt.figure(figsize=(20,8))     #width and height
sns.countplot(x='sentiment',data=combined_df, palette = 'inferno', linewidth=2, edgecolor='black')
plt.title("Distibution of the Sentiment Analysis")
plt.xlabel('Sentiment')
plt.ylabel('Frequency')

# Add annotations to plot
for p in plt.gca().patches:
    plt.gca().annotate(p.get_height(), 
                       (p.get_x()+p.get_width()/2., 
                        p.get_height()), ha='center', 
                        va='center', xytext=(0, 10), 
                        textcoords='offset points', 
                        fontsize=12, color='black',
                          weight='bold')

# %% [markdown]
# {'Neutral': 37427, 'Positive': 20020, 'Negative': 6813}
#
# The bar chart of the sentiment column shows the following distribution:
#
# Neutral: The majority of the entries are neutral, with a total of 37,427 occurrences.
# Positive: The second most common sentiment is positive, with 20,020 occurrences.
# Negative: Negative sentiment has the fewest occurrences, with 6,813.
#
# This distribution suggests that the dataset contains a significant number of neutral sentiments, which could indicate either a balanced view or a lack of strong opinions in the text data. Positive sentiments are also well-represented, showing a good amount of positive feedback or opinions. Negative sentiments are less frequent, which could be seen as a positive aspect if the data relates to customer feedback or public opinion.

# %%
# Checking for Distribution of Engagement
engagement_metrics = ['comments', 'retweets', 'quotes', 'likes']
combined_df[engagement_metrics].hist(figsize=(12, 8), bins=2)
plt.suptitle('Distribution of Engagement Metrics', y=1.02)
plt.show()

# %%
# Distribution of numerical columns
combined_df.hist(bins=20, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Columns', y=0.92)
plt.show()

# %% [markdown]
# Comments, Retweets, Quotes, Likes, Total Engagement: These columns represent engagement metrics and seem to be right-skewed, indicating that there are a few posts with very high engagement and many with low engagement.
#
# Length: This likely represents the length of the text content. The distribution seems to be fairly uniform, suggesting that the length of the text varies widely across the dataset.
#
# Day(month): This column appears to have a uniform distribution, which is expected as it likely represents the days of the month.
#
# Year: Since the dataset is likely from a specific time frame, the year column shows a spike, indicating a concentration of data from that year.
#
# Hour: The distribution of posts by hour seems to be somewhat uniform with slight variations, suggesting that posts are made at all hours of the day with some preferred times.
#
# Subjectivity: The distribution is somewhat uniform with a slight concentration around the middle, indicating that the text content varies in subjectivity.
#
# Polarity: The polarity histogram shows that most text content tends to be neutral, with fewer instances of highly positive or negative sentiment.

# %%
# Correlation matrix
corr_matrix = combined_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
Processed_df['text_temp'] = Processed_df['preprocessed_text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in Processed_df['text_temp'] for item in sublist])
temp = pd.DataFrame(top.most_common(10))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a284a_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a284a_row1_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_a284a_row2_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_a284a_row3_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_a284a_row4_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_a284a_row5_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a284a_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_a284a_row7_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_a284a_row8_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_a284a_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a284a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a284a_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_a284a_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a284a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a284a_row0_col0" class="data row0 col0" >gilbeys</td>
#       <td id="T_a284a_row0_col1" class="data row0 col1" >14065</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a284a_row1_col0" class="data row1 col0" >tusker</td>
#       <td id="T_a284a_row1_col1" class="data row1 col1" >8992</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a284a_row2_col0" class="data row2 col0" >na</td>
#       <td id="T_a284a_row2_col1" class="data row2 col1" >5233</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a284a_row3_col0" class="data row3 col0" >guinness</td>
#       <td id="T_a284a_row3_col1" class="data row3 col1" >4608</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a284a_row4_col0" class="data row4 col0" >eabl</td>
#       <td id="T_a284a_row4_col1" class="data row4 col1" >4375</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a284a_row5_col0" class="data row5 col0" >ya</td>
#       <td id="T_a284a_row5_col1" class="data row5 col1" >3217</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a284a_row6_col0" class="data row6 col0" >tickets</td>
#       <td id="T_a284a_row6_col1" class="data row6 col1" >3129</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a284a_row7_col0" class="data row7 col0" >lager</td>
#       <td id="T_a284a_row7_col1" class="data row7 col1" >2809</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a284a_row8_col0" class="data row8 col0" >ni</td>
#       <td id="T_a284a_row8_col1" class="data row8 col1" >2775</td>
#     </tr>
#     <tr>
#       <th id="T_a284a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a284a_row9_col0" class="data row9 col0" >ad</td>
#       <td id="T_a284a_row9_col1" class="data row9 col1" >2719</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plotting top 10 most frequent words using seaborn.
plt.figure(figsize=(20,8))
sns.set_style("whitegrid")
ax = sns.barplot(x="count",y="Common_words", data=temp, palette="inferno", linewidth=2,edgecolor='green')
plt.title("Most Common Words in Tweet Text")
plt.xlabel("Number of Occurrences")
plt.ylabel("Common Words")

# Addd annotaions for the barplots.
for i,j in enumerate(temp["count"]):
    ax.text(.7,i,j,weight="bold",color="white",fontsize=12)

plt.show()

# %%
#Character Counts by Tweet text
def _get_charcounts(x):
    r = x.split()
    b= ''.join(s)
    return len(x)

# %%
# getting the character length for each tweet
Processed_df['text_len'] = Processed_df['text'].apply(lambda x:len(x))

display(Processed_df['text_len'].describe())

# plotting the distribution of the tweet length
plt.figure(figsize=(10,6))
sns.distplot(Processed_df['text_len'], color='teal',kde=False, hist_kws=dict(edgecolor="red", linewidth=2), bins=50)
plt.title('The Distribution of the Text Length')
plt.xlabel('Text Length')
plt.ylabel('Count')

plt.show()
# Out:
# count    63761.000000
# mean       102.710481
# std        107.473079
# min          6.000000
# 25%         34.000000
# 50%         75.000000
# 75%        153.000000
# max       4595.000000
# Name: text_len, dtype: float64

# %%
#Word Count by Tweet
def _get_wordcounts(x):
    length = len(str(x).split())
    return length

Processed_df['word_counts'] = Processed_df['preprocessed_text'].apply(lambda x:_get_wordcounts(x))

display(Processed_df[['preprocessed_text','word_counts']].sample(5))

Processed_df['word_counts'].describe()

# plot word_counts
plt.figure(figsize=(10,8))
sns.distplot(Processed_df['word_counts'], color='teal', kde=False, hist_kws=dict(edgecolor="black", linewidth=2))
plt.title('The Distribution of the Word Counts')
plt.xlabel('Word Counts')
plt.ylabel('Count')


plt.show()
# Out:
#                                                                                                                                                                                                                         preprocessed_text  \
# 21304                                                                                                                                                                                                                            love man
# 61877                         johnnie walker blue label lunar new year 2024 year wood dragon 750ml wood dragon emerges ancient forest symbol life creativity ltd ed design drinkbetterexperiencemore johnniewalker johnniewalkerbluelabel
# 43097                                                                                                                                                                                                                     gilbeys ni wewe
# 2739                                                                                                                                                                              knh ward 6b real customers suffering cares die everyday
# 37837  tension high pale ack kapsokio pastor prugut alikuwa anarudisha padri prayers hapo kwetuwhile prugut negotiating 27 corners chepsangorchupa ya gilbeys yenye chemeli alisahau kwa gari ikalose stability ikaangukia miguu ya padri
#
#        word_counts
# 21304            2
# 61877           26
# 43097            3
# 2739             9
# 37837           31

# %% [markdown]
# The histogram shows that the most common word count is between 20 and 50. The distribution is skewed to the left, meaning that there are more tweets with lower word counts than higher word counts.

# %%
# Character Count by Sentiment
plt.figure(figsize=(10, 8))
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Positive']['text_len'], color='green', label='Positive', shade=False)
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Negative']['text_len'], color='red', label='Negative', shade=False)
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Neutral']['text_len'], color='blue', label='Neutral', shade=False)
plt.title('The Distribution of the Text Length by Sentiment')
plt.legend()

plt.show()

# %%
# word_count by sentiment type
plt.figure(figsize=(10, 6))
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Positive']['word_counts'], color='green', label='Positive', shade=False)
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Negative']['word_counts'], color='red', label='Negative', shade=False)
sns.kdeplot(Processed_df[Processed_df['sentiment'] == 'Neutral']['word_counts'], color='blue', label='Neutral', shade=False)
plt.title('The Distribution of the Word Counts by Sentiment')
plt.legend()

plt.show()

# %% [markdown]
# # Sentiment Analysis
# Distribution of Sentiments

# %%
Processed_df['sentiment'].value_counts()
# Out:
# Neutral     37079
# Positive    19903
# Negative     6779
# Name: sentiment, dtype: int64

# %%
#bargraph plot for sentiment analysis
plt.figure(figsize=(20,8)) #width and height    
sns.countplot(x='sentiment',data=Processed_df, palette = 'inferno', linewidth=2, edgecolor='black')
plt.title("Distibution of the Sentiment Analysis")
plt.xlabel('Sentiment')
plt.ylabel('Frequency')

# Add annotations to plot
for n in plt.gca().patches:
    plt.gca().annotate(p.get_height(), 
                       (p.get_x()+p.get_width()/2., 
                        p.get_height()), ha='center', 
                        va='center', xytext=(0, 10), 
                        textcoords='offset points', 
                        fontsize=12, color='black',
                          weight='bold')


plt.show()

# %%
#Positive sentiment analysis
# Most common positive words
Processed_df_pos = Processed_df[Processed_df['sentiment'] == 'Positive']
top = Counter([item for sublist in Processed_df_pos['text_temp'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_5fa5a_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5fa5a_row1_col1 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_5fa5a_row2_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_5fa5a_row3_col1 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_5fa5a_row4_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_5fa5a_row5_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_5fa5a_row6_col1, #T_5fa5a_row7_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_5fa5a_row8_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_5fa5a_row9_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_5fa5a_row10_col1, #T_5fa5a_row11_col1, #T_5fa5a_row12_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_5fa5a_row13_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_5fa5a_row14_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_5fa5a_row15_col1, #T_5fa5a_row16_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_5fa5a_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_5fa5a_row18_col1, #T_5fa5a_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5fa5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fa5a_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_5fa5a_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fa5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fa5a_row0_col0" class="data row0 col0" >tusker</td>
#       <td id="T_5fa5a_row0_col1" class="data row0 col1" >3560</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fa5a_row1_col0" class="data row1 col0" >gilbeys</td>
#       <td id="T_5fa5a_row1_col1" class="data row1 col1" >3448</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5fa5a_row2_col0" class="data row2 col0" >good</td>
#       <td id="T_5fa5a_row2_col1" class="data row2 col1" >1883</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5fa5a_row3_col0" class="data row3 col0" >guinness</td>
#       <td id="T_5fa5a_row3_col1" class="data row3 col1" >1593</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5fa5a_row4_col0" class="data row4 col0" >enjoy</td>
#       <td id="T_5fa5a_row4_col1" class="data row4 col1" >1487</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5fa5a_row5_col0" class="data row5 col0" >ad</td>
#       <td id="T_5fa5a_row5_col1" class="data row5 col1" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5fa5a_row6_col0" class="data row6 col0" >eabl</td>
#       <td id="T_5fa5a_row6_col1" class="data row6 col1" >1420</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5fa5a_row7_col0" class="data row7 col0" >tickets</td>
#       <td id="T_5fa5a_row7_col1" class="data row7 col1" >1416</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5fa5a_row8_col0" class="data row8 col0" >na</td>
#       <td id="T_5fa5a_row8_col1" class="data row8 col1" >1308</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5fa5a_row9_col0" class="data row9 col0" >today</td>
#       <td id="T_5fa5a_row9_col1" class="data row9 col1" >1227</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5fa5a_row10_col0" class="data row10 col0" >love</td>
#       <td id="T_5fa5a_row10_col1" class="data row10 col1" >1219</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5fa5a_row11_col0" class="data row11 col0" >opengoodtimes</td>
#       <td id="T_5fa5a_row11_col1" class="data row11 col1" >1219</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5fa5a_row12_col0" class="data row12 col0" >live</td>
#       <td id="T_5fa5a_row12_col1" class="data row12 col1" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5fa5a_row13_col0" class="data row13 col0" >new</td>
#       <td id="T_5fa5a_row13_col1" class="data row13 col1" >1176</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5fa5a_row14_col0" class="data row14 col0" >cider</td>
#       <td id="T_5fa5a_row14_col1" class="data row14 col1" >1122</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5fa5a_row15_col0" class="data row15 col0" >best</td>
#       <td id="T_5fa5a_row15_col1" class="data row15 col1" >1054</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5fa5a_row16_col0" class="data row16 col0" >ticket</td>
#       <td id="T_5fa5a_row16_col1" class="data row16 col1" >1049</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5fa5a_row17_col0" class="data row17 col0" >buy</td>
#       <td id="T_5fa5a_row17_col1" class="data row17 col1" >1033</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5fa5a_row18_col0" class="data row18 col0" >lager</td>
#       <td id="T_5fa5a_row18_col1" class="data row18 col1" >1015</td>
#     </tr>
#     <tr>
#       <th id="T_5fa5a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5fa5a_row19_col0" class="data row19 col0" >ready</td>
#       <td id="T_5fa5a_row19_col1" class="data row19 col1" >1015</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plotting a tree map to show the positive sentiments
plt.figure(figsize=(20,8))

# Create labels with word counts
label_pos= [f"{word}\n{count}" for word, count in zip(temp_positive['Common_words'], temp_positive['count'])]

# Use a valid colormap name, for example, 'viridis'
squarify.plot(sizes=temp_positive['count'], label=label_pos, alpha=0.8, color=sns.color_palette("viridis", 10), text_kwargs={'fontsize':10})

plt.title('Tree Map of the Most Common Positive Words')
plt.axis('off')
plt.show()

# %%
# Getting the most positive tweets

y = 1
sortedDF = Processed_df.sort_values(by = ['Polarity'], ascending = False).reset_index(drop=True)
positive_tweets = []  # list to store positive tweets
for i in range(0, sortedDF.shape[0]):
  if(sortedDF['sentiment'][i] == 'Positive'):
    positive_tweets.append(sortedDF['text'][i])
    y = y+1

# Convert list to DataFrame
positive_tweets_df = pd.DataFrame(positive_tweets, columns=['Positive Tweets'])

positive_tweets_df
# Out:
#                                                                                                                                                                                                                                              Positive Tweets
# 0                                                                                                                                                                    kalenjin women are the best as wives fr i am talking about vienyejis si hawa wa gilbeys
# 1                                     yooh tufike thorn treekibera tukamate gilbeys remember for any purchase of bucket of beer or spirit you shall be served with a delicious mbuzi beiyajioni courtesy of kumbuka drinkbetternotmore check out to see your
# 2                                                                                                                                                                               gilbeys ndio best quickmart supermarket quickmart offer quickmartcrazyoffers
# 3                                                                                                                                   the hennessy too went through the shaking ordeal muratina wine changaa busaa best pilsner jd jw gilbeysyote ni pombe imo
# 4                                                                                                                                                                              try the guinness challenge first sip must perfectly underline guinness cheers
# ...                                                                                                                                                                                                                                                      ...
# 19898                                what do you prefer roasted chicken or goats meat anyway get ready to enjoy your fav bites at roastandrhyme this sunday grab a ticket via roastandrhymecom or dail 291 at just 100k cheerstotheholidays thisishowwedo cc
# 19899                                 ad enjoy opengoodtimes at the mixedandmatched pinknic with at absa grounds 28th jan 3pm late dress code mixmatch with a touch of pink tickets 1 350ml gilbeys mixed berries 1 1 750ml 2 2 750ml squad tickets 5 people
# 19900                                 ad enjoy opengoodtimes at the mixedandmatched pinknic with at absa grounds 28th jan 3pm late dress code mixmatch with a touch of pink tickets 1 350ml gilbeys mixed berries 1 1 750ml 2 2 750ml squad tickets 5 people
# 19901                                                                  this packaging is so cheap looks horrible eastafricanbreweries pls come up with better packaging or revert back to the old packaging this is not kenya cane class smirnoff eabl vodka
# 19902  the joy of finding secret places to watch elephants without disturbing them travelsrilanka srilanka travel srilankansafari canonsl nature safari wild wildlifephotography naturephotography canonasia elephant srilankanelephant asianelephant tusker
#
# [19903 rows x 1 columns]

# %% [markdown]
# # Negative Sentiment Analysis

# %%
# Most Common Negative Words
Processed_df_neg = Processed_df[Processed_df['sentiment'] == 'Negative']
top = Counter([item for sublist in Processed_df_neg['text_temp'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_0ff57_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0ff57_row1_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_0ff57_row2_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_0ff57_row3_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_0ff57_row4_col1, #T_0ff57_row5_col1, #T_0ff57_row6_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_0ff57_row7_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_0ff57_row8_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_0ff57_row9_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_0ff57_row10_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_0ff57_row11_col1, #T_0ff57_row12_col1, #T_0ff57_row13_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_0ff57_row14_col1, #T_0ff57_row15_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_0ff57_row16_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_0ff57_row17_col1, #T_0ff57_row18_col1, #T_0ff57_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0ff57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ff57_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_0ff57_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ff57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ff57_row0_col0" class="data row0 col0" >gilbeys</td>
#       <td id="T_0ff57_row0_col1" class="data row0 col1" >1711</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ff57_row1_col0" class="data row1 col0" >tusker</td>
#       <td id="T_0ff57_row1_col1" class="data row1 col1" >766</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ff57_row2_col0" class="data row2 col0" >na</td>
#       <td id="T_0ff57_row2_col1" class="data row2 col1" >729</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ff57_row3_col0" class="data row3 col0" >eabl</td>
#       <td id="T_0ff57_row3_col1" class="data row3 col1" >722</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ff57_row4_col0" class="data row4 col0" >ad</td>
#       <td id="T_0ff57_row4_col1" class="data row4 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ff57_row5_col0" class="data row5 col0" >guinness</td>
#       <td id="T_0ff57_row5_col1" class="data row5 col1" >546</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ff57_row6_col0" class="data row6 col0" >mixed</td>
#       <td id="T_0ff57_row6_col1" class="data row6 col1" >546</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ff57_row7_col0" class="data row7 col0" >opengoodtimes</td>
#       <td id="T_0ff57_row7_col1" class="data row7 col1" >534</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ff57_row8_col0" class="data row8 col0" >tickets</td>
#       <td id="T_0ff57_row8_col1" class="data row8 col1" >487</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ff57_row9_col0" class="data row9 col0" >ticket</td>
#       <td id="T_0ff57_row9_col1" class="data row9 col1" >441</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0ff57_row10_col0" class="data row10 col0" >ya</td>
#       <td id="T_0ff57_row10_col1" class="data row10 col1" >431</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0ff57_row11_col0" class="data row11 col0" >pale</td>
#       <td id="T_0ff57_row11_col1" class="data row11 col1" >420</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0ff57_row12_col0" class="data row12 col0" >mixedandmatched</td>
#       <td id="T_0ff57_row12_col1" class="data row12 col1" >420</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0ff57_row13_col0" class="data row13 col0" >black</td>
#       <td id="T_0ff57_row13_col1" class="data row13 col1" >416</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0ff57_row14_col0" class="data row14 col0" >ni</td>
#       <td id="T_0ff57_row14_col1" class="data row14 col1" >399</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0ff57_row15_col0" class="data row15 col0" >absa</td>
#       <td id="T_0ff57_row15_col1" class="data row15 col1" >396</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0ff57_row16_col0" class="data row16 col0" >bottle</td>
#       <td id="T_0ff57_row16_col1" class="data row16 col1" >370</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0ff57_row17_col0" class="data row17 col0" >redeemable</td>
#       <td id="T_0ff57_row17_col1" class="data row17 col1" >356</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0ff57_row18_col0" class="data row18 col0" >grounds</td>
#       <td id="T_0ff57_row18_col1" class="data row18 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_0ff57_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0ff57_row19_col0" class="data row19 col0" >buy</td>
#       <td id="T_0ff57_row19_col1" class="data row19 col1" >352</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plotting a tree map to show the negative sentiments
plt.figure(figsize=(20,8))

# Create labels with word counts
labels_neg = [f"{word}\n{count}" for word, count in zip(temp_negative['Common_words'], temp_negative['count'])]

squarify.plot(sizes=temp_negative['count'], label=labels_neg, alpha=0.8, color=sns.color_palette("Reds", 20), text_kwargs={'fontsize':20})

plt.title('Tree Map of the Most Common Negative Words')
plt.axis('off')

plt.show()

# %%
# Getting the most negative tweets

y = 1
sortedDF = Processed_df.sort_values(by = ['Polarity'], ascending = False).reset_index(drop=True)
Processed_negative_tweets = []  # list to store negative tweets
for i in range(0, sortedDF.shape[0]):
  if(sortedDF['sentiment'][i] == 'Negative'):
    Processed_negative_tweets.append(sortedDF['clean_text'][i])
    y = y+1

# Convert list to DataFrame
Processed_negative_tweets = pd.DataFrame(Processed_negative_tweets, columns=['Negative Tweets'])

Processed_negative_tweets
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                       Negative Tweets
# 0                                                                                                                                                                                                                                                                                                          rare giant tusker elephant killed poachers 25 left wild giant tusker elephant killed poachers dlvritnyxkld
# 1                                                                                                                                                                                                                                                    artistes remixes drag think saving lame screenshot reason use time wisely stream favs snoozefest album atleast jk 6 individual guinness world records cry harder
# 2                                                                                                                                                                                                                                     big things come huge packages tusker casually strolling mara puny landcruiser looks marben saturdaymotivation onerainbow safari safariweek masaimara holiday wild traveldiaries
# 3     day 1984 rts today tonight broadcast landmark programme aftermath tidey kidnapping programme presented brendan obrien set answer unanswered questions circumstances kidnapping murder recruit garda gary sheehan private patrick kelly derrada wood outside ballinamore kidnappers vastly outnumbered manage shoot way safety escaped socalled ring steel chosen leitrim support county revealed ring steel ...
# 4                                                                                                                                                                                                                                                                                                                   lie meets honest relationship trust lies wrong yes mental issues accept lies living fantasy world
# ...                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 6774                                                                                                                                                                                                                                                                                                                                                                       buying gilbeys 750ml 4500 shillings insane
# 6775                                                                                                                                                                                                                                                                                                                                                      insane gm tweet starts players accountable roster looks way
# 6776                                                                                                                                                                                                                                                                                                                                                              gilbeys definitely worst drink waah heri bestchrome
# 6777                                                                                                                                                                                                                                                                  bholaashankar ki 5 ichinappdu shocking ani kakunda pachha manda antha essays raasaaru kada ra cut cheste okkati kuda nijam leni stories rastaru
# 6778                                                                                                                                                                                                                                                                                                                                                                          worst thay happen chase gilbeys baileys
#
# [6779 rows x 1 columns]

# %% [markdown]
# # Neutral Sentiment Analysis

# %%
# Most Common Neutral Words
df_neu = Processed_df[Processed_df['sentiment'] == 'Neutral']
top = Counter([item for sublist in df_neu['text_temp'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_69609_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_69609_row1_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_69609_row2_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_69609_row3_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_69609_row4_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_69609_row5_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_69609_row6_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_69609_row7_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_69609_row8_col1, #T_69609_row9_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_69609_row10_col1, #T_69609_row11_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_69609_row12_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_69609_row13_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_69609_row14_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_69609_row15_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_69609_row16_col1, #T_69609_row17_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_69609_row18_col1, #T_69609_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_69609">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69609_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_69609_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69609_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69609_row0_col0" class="data row0 col0" >gilbeys</td>
#       <td id="T_69609_row0_col1" class="data row0 col1" >8906</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69609_row1_col0" class="data row1 col0" >tusker</td>
#       <td id="T_69609_row1_col1" class="data row1 col1" >4666</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69609_row2_col0" class="data row2 col0" >na</td>
#       <td id="T_69609_row2_col1" class="data row2 col1" >3196</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69609_row3_col0" class="data row3 col0" >guinness</td>
#       <td id="T_69609_row3_col1" class="data row3 col1" >2469</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69609_row4_col0" class="data row4 col0" >eabl</td>
#       <td id="T_69609_row4_col1" class="data row4 col1" >2233</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69609_row5_col0" class="data row5 col0" >ya</td>
#       <td id="T_69609_row5_col1" class="data row5 col1" >2149</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69609_row6_col0" class="data row6 col0" >ni</td>
#       <td id="T_69609_row6_col1" class="data row6 col1" >1564</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69609_row7_col0" class="data row7 col0" >lager</td>
#       <td id="T_69609_row7_col1" class="data row7 col1" >1473</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69609_row8_col0" class="data row8 col0" >de</td>
#       <td id="T_69609_row8_col1" class="data row8 col1" >1295</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69609_row9_col0" class="data row9 col0" >buy</td>
#       <td id="T_69609_row9_col1" class="data row9 col1" >1289</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_69609_row10_col0" class="data row10 col0" >tickets</td>
#       <td id="T_69609_row10_col1" class="data row10 col1" >1226</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_69609_row11_col0" class="data row11 col0" >bell</td>
#       <td id="T_69609_row11_col1" class="data row11 col1" >1223</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_69609_row12_col0" class="data row12 col0" >captain</td>
#       <td id="T_69609_row12_col1" class="data row12 col1" >1173</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_69609_row13_col0" class="data row13 col0" >morgan</td>
#       <td id="T_69609_row13_col1" class="data row13 col1" >1092</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_69609_row14_col0" class="data row14 col0" >mixed</td>
#       <td id="T_69609_row14_col1" class="data row14 col1" >1041</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_69609_row15_col0" class="data row15 col0" >berries</td>
#       <td id="T_69609_row15_col1" class="data row15 col1" >954</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_69609_row16_col0" class="data row16 col0" >boycotteabl</td>
#       <td id="T_69609_row16_col1" class="data row16 col1" >914</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_69609_row17_col0" class="data row17 col0" >chromegin</td>
#       <td id="T_69609_row17_col1" class="data row17 col1" >911</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_69609_row18_col0" class="data row18 col0" >kwa</td>
#       <td id="T_69609_row18_col1" class="data row18 col1" >859</td>
#     </tr>
#     <tr>
#       <th id="T_69609_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_69609_row19_col0" class="data row19 col0" >going</td>
#       <td id="T_69609_row19_col1" class="data row19 col1" >839</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(20,8))

# Create labels with word counts
word_neu = [f"{word}\n{count}" for word, count in zip(temp_positive['Common_words'], temp_positive['count'])]

squarify.plot(sizes=temp_neutral['count'], label=word_neu, alpha=0.8, color=sns.color_palette("Greens", 10), text_kwargs={'fontsize':10})

plt.title('Tree Map of the Most Common Neutral Words')
plt.axis('off')

plt.show()

# %%
# Getting the most Neutral tweets

y = 1
sortedDF = Processed_df.sort_values(by = ['Polarity'], ascending = False).reset_index(drop=True)
Neutral_tweets = []  # list to store Neutral tweets
for i in range(0, sortedDF.shape[0]):
  if(sortedDF['sentiment'][i] == 'Neutral'):
    Neutral_tweets.append(sortedDF['text'][i])
    y = y+1

# Convert list to DataFrame
Neutral_tweets_df = pd.DataFrame(Neutral_tweets, columns=['Neutral Tweets'])

Neutral_tweets_df
# Out:
#                                                                                                                                                                   Neutral Tweets
# 0                                                                                                                                                                        gilbeys
# 1                                                                                                                               los niu los nuevos para los que no sepan inglich
# 2                                                                                                                                            hurdles gunturkaaram sunc avvatlede
# 3                                                                                                  bu arada bilen bilir gordonsn olduu yerde gilbeys dezenfektan olarak kullanlr
# 4                                                         asalu sandhya70 tickets okkataina konnarani kani ila evaro show teeskunnarani ekkadaina chusava least talked topic idi
# ...                                                                                                                                                                          ...
# 37074  ray epps the man who directed people to go into the capitol and privately claimed credit for orchestrating the capitol breach gets one year probation nothing to see here
# 37075                                                                                                                                                            lets be mutuals
# 37076                                                                                              snow plowing is finished up time for a captain morgan and watch the fire burn
# 37077                                                                                                                       2023 nfl fan of the year presented by captain morgan
# 37078                                                                                                                                             i thought levis was the answer
#
# [37079 rows x 1 columns]

# %%
pip install --upgrade Pillow wordcloud
# Out:
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\lib\site-packages (10.2.0)
# Requirement already satisfied: wordcloud in c:\users\user\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools
# Out:
# Requirement already satisfied: pip in c:\users\user\anaconda3\lib\site-packages (23.3.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (69.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#plotting a word cloud for the entire dataset
# Combining all the text data into a single string
text = ' '.join(Processed_df['text'])

# Generating the word cloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate(text)

# Plot the word cloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %%
# save the dataframe to csv using the name 'processed_data.csv'

Final_df = Processed_df[['clean_text', 'preprocessed_text', 'lemma_preprocessed_text', 'stemma_preprocessed_text', 'sentiment']]
Final_df.to_csv('Final_data.csv', index=False)

# %% [markdown]
# # Modelling

# %% [markdown]
# In sentiment analysis, where the goal is to classify text into different sentiment categories (such as positive, negative, or neutral), several metrics can be used to evaluate the performance of a model. In our case, the metric of success to be used will be the F1 score, precision and recall.
#
# Precision and recall provide insights into the model's performance in correctly predicting positive instances and capturing all relevant positive instances, respectively. Precision is the ratio of true positives to the sum of true positives and false positives, while recall is the ratio of true positives to the sum of true positives and false negatives.
#
# Precision emphasizes the quality of positive predictions, while recall emphasizes the completeness of positive predictions
#
# The F1 score is the harmonic mean of precision and recall, providing a balance between the two metrics. It is particularly useful when there is an uneven distribution of classes in the dataset.

# %%
final_df = pd.read_csv('Final_data.csv')

final_df.head()
# Out:
#                                                                                                                                                                                  clean_text  \
# 0  guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                             drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                          kenyans wakitambua hii beer eabl
# 3                                                                                                                                                   thought eabl products unwanted mountain
# 4                                                                    unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                                           preprocessed_text  \
# 0  guys remember shaffie weru dj joe mfalmeneville musya fired home boys radio coz warned ladies happened starlet wahu pastor kanyari sizeabl got mad coz ladies listened likes john matara
# 1                             drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati towns free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                          kenyans wakitambua hii beer eabl
# 3                                                                                                                                                   thought eabl products unwanted mountain
# 4                                                                    unajua sai amafanya eabl anaweza tupea years supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                              lemma_preprocessed_text  \
# 0  guy remember shaffie weru dj joe mfalmeneville musya fired home boy radio coz warned lady happened starlet wahu pastor kanyari sizeabl got mad coz lady listened like john matara
# 1                       drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati town free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                    kenyan wakitambua hii beer eabl
# 3                                                                                                                                             thought eabl product unwanted mountain
# 4                                                              unajua sai amafanya eabl anaweza tupea year supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#                                                                                                                                                 stemma_preprocessed_text  \
# 0  guy rememb shaffi weru dj joe mfalmenevil musya fire home boy radio coz warn ladi happen starlet wahu pastor kanyari sizeabl got mad coz ladi listen like john matara
# 1                    drill water kenneth matiba hospit makenji kandara gatanga near kenol kabati town free donat eabl muranga counti eabl partnership sorghum thank eabl
# 2                                                                                                                                        kenyan wakitambua hii beer eabl
# 3                                                                                                                                   thought eabl product unwant mountain
# 4                                                   unajua sai amafanya eabl anaweza tupea year suppli ya balozi na singleton kama yobra wew unapepeta tutablockiwa bana
#
#   sentiment
# 0  Negative
# 1  Positive
# 2   Neutral
# 3   Neutral
# 4   Neutral

# %%
final_df=final_df[['lemma_preprocessed_text','sentiment']]
final_df.head()
# Out:
#                                                                                                                                                              lemma_preprocessed_text  \
# 0  guy remember shaffie weru dj joe mfalmeneville musya fired home boy radio coz warned lady happened starlet wahu pastor kanyari sizeabl got mad coz lady listened like john matara
# 1                       drilling water kenneth matiba hospital makenji kandara gatanga near kenol kabati town free donation eabl muranga county eabl partnership sorghum thanks eabl
# 2                                                                                                                                                    kenyan wakitambua hii beer eabl
# 3                                                                                                                                             thought eabl product unwanted mountain
# 4                                                              unajua sai amafanya eabl anaweza tupea year supply ya balozi na singleton kama yobra wewe unapepeta tutablockiwa bana
#
#   sentiment
# 0  Negative
# 1  Positive
# 2   Neutral
# 3   Neutral
# 4   Neutral

# %%
#creating a function to get all columns of object type
obj_list = final_df.select_dtypes(include = "object").columns
print (obj_list)
# Out:
# Index(['lemma_preprocessed_text', 'sentiment'], dtype='object')

# %%
# import train test split and splitting the dataset
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(final_df['lemma_preprocessed_text'],
                                                    final_df['sentiment'],
                                                    test_size=0.2,
                                                    random_state = 0)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((51008,), (12753,), (51008,), (12753,))

# %%
#using label encode to encode the categorical columns
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# transforming y_train and y_test
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

le.classes_
# Out:
# array(['Negative', 'Neutral', 'Positive'], dtype=object)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\user\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.10.1)

# %%
import xgboost as xgb
from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)

# Transform the test data
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Convert inputs to DMatrix format for XGBoost
dtrain = xgb.DMatrix(X_train_tfidf, label=y_train)
dtest = xgb.DMatrix(X_test_tfidf, label=y_test)


# Define XGBoost model parameters
params = {'objective': 'multi:softmax', 'num_class': 3, 'max_depth': 6,
          'eta': 0.3, 'subsample': 0.6, 'colsample_bytree': 0.8}

# Train the XGBoost model
num_rounds = 50
xgb_model = xgb.train(params, dtrain, num_rounds)

# Use the XGBoost model to make predictions on the test set
xgb_pred = xgb_model.predict(dtest)

# Evaluate the performance
from sklearn.metrics import classification_report,confusion_matrix

confusion_matrix = confusion_matrix(y_test, xgb_pred)
print(confusion_matrix)
print('--------------------------------------------------------------------------')
print(classification_report(y_test, xgb_pred))
#print('Accuracy of our model is' + ' ' + str(accuracy_score(y_test, xgb_pred)))
# Out:
# [[ 665  624   75]
#  [  17 7361   24]
#  [  85  938 2964]]
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.49      0.62      1364
#            1       0.82      0.99      0.90      7402
#            2       0.97      0.74      0.84      3987
#
#     accuracy                           0.86     12753
#    macro avg       0.89      0.74      0.79     12753
# weighted avg       0.87      0.86      0.85     12753

# %% [markdown]
# For class 0, the model has a precision of 0.87, meaning that when it predicts class 0, it is correct 87% of the time. The recall is 0.49 which means that the model is capturing only the 49% of instances of class 0. The F1 score that takes care of both precision and recall at a time is 0.62.
#
# For instance, for class 1, the model has a high precision of 0.82 implying that when it predicts for class one, its correctness is in 82% of the cases. Recall is very high at 0.99, meaning almost every instance of class 1 is captured in the model. The F1-score is also high at 0.90.
#
# The model has high precision for class 2 of 0.97 meaning that when the class 2 is predicted, then the prediction will be correct in 97% of cases. The recall is 0.74 and thus the model captures only 74% of instances where actual class is 2. The F1-score is 0.84.

# %% [markdown]
# # Second model-Logistic regression

# %%
from sklearn.metrics import classification_report, roc_curve, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
def multiclass_evaluation(y_true, y_pred, X_test, X_train, clf, n_class=3):
    
    #training and test scores
    print(f"Training Score: {round(clf.score(X_train, y_train),2)} \
            Test Score:{round(clf.score(X_test, y_true),2)}")
    
    #Classification report
    print("\n")
    print("CLASSIFICATION REPORT")
    print("------------------------------------------")
    print(classification_report(y_true=y_true, y_pred=y_pred))
    
    #Creating a figure/axes for confusion matrix and ROC curve
    fig, ax = plt.subplots(ncols=2, figsize=(20, 8))
    
    #Plotting the normalized confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, 
                           display_labels=['Negative', 'Neutral', 'Positive'])
    disp.plot(ax=ax[0], cmap='Greens')
    ax[0].grid(False)  # Remove gridlines
    
    pred_prob = clf.predict_proba(X_test)
    
    #Plotting the ROC curve
    fpr={}
    tpr={}
    thresh={}
    
    for i in range(n_class):    
        fpr[i], tpr[i], thresh[i] = roc_curve(y_true, pred_prob[:,i], pos_label=i)
    
    ax[1].plot(fpr[0], tpr[0], linestyle='--',color='red', label='Negative vs Rest')
    ax[1].plot(fpr[1], tpr[1], linestyle='--',color='blue', label='Neutral vs Rest')
    ax[1].plot(fpr[2], tpr[2], linestyle='--',color='green', label='Positive vs Rest')
    ax[1].set_title('Multiclass ROC curve')
    ax[1].set_xlabel('False Positive Rate')
    ax[1].set_ylabel('True Positive rate')
    ax[1].legend(loc='best')
    
    #Plotting the 50-50 guessing plot for reference
    ax[1].plot([0,1], [0,1], ls='--', color='orange')

# %% [markdown]
# Baseline Logistic Regression Model

# %%
log_base_clf = Pipeline([('vectorizer', TfidfVectorizer()),
                                ('classifier', LogisticRegression())])

log_base_clf.fit(X_train, y_train)

# Making our predictions
y_pred = log_base_clf.predict(X_test)


multiclass_evaluation(y_test, y_pred, X_test, X_train, log_base_clf, n_class=3)
# Out:
# Training Score: 0.95             Test Score:0.91
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.61      0.73      1364
#            1       0.90      0.99      0.94      7402
#            2       0.95      0.88      0.91      3987
#
#     accuracy                           0.91     12753
#    macro avg       0.92      0.82      0.86     12753
# weighted avg       0.92      0.91      0.91     12753

# %% [markdown]
# For class zero, precision at 0.90 means that from the instances which the model had predicted to be class 0, 90% is true. The recall at 0.61 means that only 61% of all actual instances of class 0 are identified by the model. The F1-score is at 0.73 which is the harmonic mean of precision and recall.
#
# Class 1 has a model precision that lies at a high of 90%, meaning there is a low false positive rate. A recall of 0.99 indicates almost every value for class 1 has been captured by the model. The F1-score of 0.94, on the other hand, means there is a good balance between precision and recall.
#
# Finally, class 2 has a high precision rate of 95% (meaning that the chance of false positives is low). In the recall of 0.88, it can be said that the model was able to detect the majority of real instances in class 2. The F1-score turned out to be 0.91, which means good overall performance.
#
# The 91% overall accuracy is a percentage of correctly classified instances over all classes. This shows how well the model did generally.

# %% [markdown]
# # Model 3: Random Forest

# %%
base_rf_clf = Pipeline([('tfidf', TfidfVectorizer()),
                        ('base_rf_clf', RandomForestClassifier(random_state=42))])

base_rf_clf.fit(X_train, y_train)

# Predicting the Test set results
y_pred = base_rf_clf.predict(X_test)
multiclass_evaluation(y_test, y_pred, X_test, X_train, base_rf_clf)
# Out:
# Training Score: 1.0             Test Score:0.93
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.63      0.75      1364
#            1       0.93      0.99      0.96      7402
#            2       0.93      0.92      0.93      3987
#
#     accuracy                           0.93     12753
#    macro avg       0.93      0.85      0.88     12753
# weighted avg       0.93      0.93      0.92     12753

# %% [markdown]
# For class 0, this is a precision of 0.92 which tells that when the model predicts class 0, then it would only be wrong 8% of the time. With a recall of 0.63, only 63% of the actual instances of class 0 would be covered by the model. The F1-score indicates the balance that exists between precision and recall with a value of 0.75.
#
# The model had a high precision of 93%, predicting class 1, showing low false positive. The recall was high at 0.99, showing that the model captures almost all class 1. The F1-score was 0.96, showing a robust balance between precision and recall.
#
# The precision of class 2 is also very high- 93%, which in itself indicates low false positive value. The recall for class 2 is 0.92, representing the ability to identify an effective number of true instances for class 2 under analysis. The F1-score is 0.93 as well which measures a good overall performance indicator.
#
# For the reason that, in this problem of classification, for all methods, accuracy is averaged out, hence the average of 93% reflects the percentage of correctly classified instances over classes. One can infer that the model has performed well due to this.

# %% [markdown]
# # Model 4: Complement Naive Bayes

# %% [markdown]
# Complement Naive Bayes (CNB) stands out as a modified version of the conventional Naive Bayes (NB) algorithm. Its design makes it particularly effective in handling imbalanced datasets, where there is a significant disparity in the distribution of classes, with one class being more prevalent than the others. CNB is tailored to address the challenges posed by skewed class distributions, making it a valuable choice in scenarios where traditional NB may encounter difficulties due to imbalances in the data.

# %%
from sklearn.naive_bayes import ComplementNB

base_nb_clf = Pipeline([('tfidf', TfidfVectorizer()),
                        ('base_nb_clf', ComplementNB())])

base_nb_clf.fit(X_train, y_train)

# Predicting the Test set results
y_pred = base_nb_clf.predict(X_test)
multiclass_evaluation(y_test, y_pred, X_test, X_train, base_nb_clf)
# Out:
# Training Score: 0.88             Test Score:0.77
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54      1364
#            1       0.90      0.75      0.82      7402
#            2       0.67      0.91      0.77      3987
#
#     accuracy                           0.77     12753
#    macro avg       0.72      0.72      0.71     12753
# weighted avg       0.79      0.77      0.77     12753

# %% [markdown]
# A precision of 0.61 for class 0 means 61% instances predicted as class 0 were correct, recall of 0.49 suggests the model is more effective in capturing all instances of class 0 while an F1-score of 0.54 is a balance between precision and recall for class 0.
#
# High precision of 0.90 for class 1 shows the fluency in the of the model to identify correctly the instances of class 1 while recall of 0.75 implies that a huge number of ’instances of class capture’ get a huge number of class 1 instances.
#
# The recall of class 2 meaning the percentage of instances with class 2 that are correctly identified is relatively high at 0.91, and its precision is 0.67, which also means that the model has a moderate prediction ability in identifying the instances with class 2.
#
# The model achieves an overall accuracy of 0.77, correctly predicting class labels for 77% of instances.

# %% [markdown]
# # Hyperparameter tuning of the models

# %% [markdown]
# ### Tuned xgboost Model

# %%
import xgboost as xgb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score

# %%
from sklearn.model_selection import RandomizedSearchCV
# Instantiating the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fitting and transform the training data
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Defining a smaller parameter grid to minimize runtime
param_dist = {
    'max_depth': [3, 6],
    'learning_rate': [0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'n_estimators': [50, 100]
}

# Using RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=xgb.XGBClassifier(objective='multi:softmax', num_class=3),
                                   param_distributions=param_dist,
                                   scoring='accuracy',
                                   cv=3,
                                   n_iter=5,
                                   verbose=2,
                                   n_jobs=-1)
random_search.fit(X_train_tfidf, y_train)

# Get the best parameters and best model
best_params = random_search.best_params_
best_model = random_search.best_estimator_

# Use the best model to make predictions on the test set
random_search_pred = best_model.predict(X_test_tfidf)

# Evaluate the performance of the best model
print("Best Parameters:", best_params)
print('--------------------------------------------------------------------------')
print("Classification Report:")
print(classification_report(y_test, random_search_pred))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# Best Parameters: {'subsample': 1.0, 'n_estimators': 50, 'max_depth': 6, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# --------------------------------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.38      0.53      1364
#            1       0.79      1.00      0.88      7402
#            2       0.97      0.70      0.81      3987
#
#     accuracy                           0.84     12753
#    macro avg       0.87      0.69      0.74     12753
# weighted avg       0.86      0.84      0.82     12753

# %% [markdown]
# Model's performance after tuning is not better than the baseline model. In class 0, the precision of the model predicting that a review will fall in the class of harmfulness is 0.84, which depicts that the model will be correct at 84% of times when it predicts a class of 0. The recall is 0.40 that means the model just being able to capture 40% of the instances of class 0. The F1-score is 0.54.
#
# The precision score for class 1 is brought down to 0.80 pointing out that the model gets its prediction right in 80% of cases when it makes a prediction as class 1. The recall is very high at 1.00 pointing out to the fact that the model has been able to capture all instances of class 1. The F1-score is also on the higher side at 0.89.
#
# For class 2, it has a high precision of 0.96 which means that when it predicts the class as 2, it actually is class 2 for 96% of the time. Recall is 0.69, which means that the model can catch only 69% of instances from class 2 with falling into class 1. The F1-score is 0.80. Average accuracy of the model has dropped to 0.84(84%). This means the tuned XGboost model correctly predicted the class labels for 84% of the instances in the dataset.

# %% [markdown]
# ### Tuned Logistic Regression model

# %%
# Defining the pipeline
tuned_log_clf = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('tuned_log_clf', LogisticRegression())
])

# Defining the parameter grid for tuning
param_grid = {
    'tuned_log_clf__C': [0.01, 0.1, 1, 10, 100],
    'tuned_log_clf__penalty': ['l1', 'l2'],
    'tuned_log_clf__solver': ['liblinear']
}

# Creating the GridSearchCV object
tuned_log_clf_CV = GridSearchCV(tuned_log_clf, param_grid, cv=5, verbose=1, n_jobs=-1)

# Fitting the model
tuned_log_clf_CV.fit(X_train, y_train)

# Making predictions on the test set
y_pred = tuned_log_clf_CV.predict(X_test)

# Performing evaluation 
multiclass_evaluation(y_test, y_pred, X_test, X_train, tuned_log_clf_CV)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training Score: 1.0             Test Score:0.97
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90      1364
#            1       0.97      0.99      0.98      7402
#            2       0.97      0.96      0.97      3987
#
#     accuracy                           0.97     12753
#    macro avg       0.96      0.94      0.95     12753
# weighted avg       0.97      0.97      0.97     12753

# %% [markdown]
# Upon tuning the model, the performance increased significantly. The precision for class zero 0.92, meaning, when this model is predicting class 0, then it is correct 92% of the time. From the recall of 0.88, it can be said that the model has captured 88% of the actual instances of class 0. The F1-score which is a balance between precision and recall comes out to be 0.90
#
# For class 1, the model has shown a high level of precision (97%) indicative of low amount of false positives. The recall of 0.99 suggests the fact that the model captures almost all instances belonging to class 1. The F1-Score is 0.98 and as such demonstrates a very robust balance between precision and recall.
#
# Class 2 has high precision at 97%, which also implies the classifier gives a low false positive rate. Recall of 0.96 means that the model captured a large proportion of actuals of class 2. The F1 score contributes to 0.97, meaning good overall performance.
#
# The overal accuracy of 97% indicates how well overall the model is at classifying instances. It actually simply well sums up what the performance of the model is about.

# %% [markdown]
# ### Tuned Random Forest model

# %%
# Define the pipeline with the RandomForestClassifier
tuned_rf_clf = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('tuned_rf_clf', RandomForestClassifier(random_state=42))
])

# Define a smaller parameter grid for quicker search
param_grid = {
    'tuned_rf_clf__n_estimators': [50, 100],
    'tuned_rf_clf__max_depth': [None, 10],
    'tuned_rf_clf__min_samples_split': [2, 5],
    'tuned_rf_clf__min_samples_leaf': [1, 2]
}

# Use a smaller number of cross-validation folds
cv_folds = 3

# Create the GridSearchCV object
tuned_rf_clf_CV = GridSearchCV(tuned_rf_clf, param_grid, cv=cv_folds, verbose=1, n_jobs=-1, scoring='accuracy')

# Fit the model
tuned_rf_clf_CV.fit(X_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", tuned_rf_clf_CV.best_params_)

# Make predictions on the test set using the best model
y_pred = tuned_rf_clf_CV.predict(X_test)

# Perform evaluation 
multiclass_evaluation(y_test, y_pred, X_test, X_train, tuned_rf_clf_CV)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best Hyperparameters: {'tuned_rf_clf__max_depth': None, 'tuned_rf_clf__min_samples_leaf': 1, 'tuned_rf_clf__min_samples_split': 5, 'tuned_rf_clf__n_estimators': 100}
# Training Score: 1.0             Test Score:0.93
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.64      0.75      1364
#            1       0.93      0.99      0.96      7402
#            2       0.93      0.92      0.93      3987
#
#     accuracy                           0.93     12753
#    macro avg       0.93      0.85      0.88     12753
# weighted avg       0.93      0.93      0.93     12753

# %% [markdown]
# The results show that after tuning the model, performance of the model has improved for class zero(0) while it is constant for classes 1 and 2. For class 0, precision of 0.93 shows that when the model predicts class 0, indeed it is correct by 93%. Here, recall is 0.64, which means actual instances of class 0 are captured by the model by just 64%. F1-score is 0.75, which is a harmonic mean of precision and recall.
#
# Precision of class 1, that is rather high (93%) means the model has a low false positive rate. Recall 0.99 suggests that in nearly 99% of the times the model is able to figure out almost all the instances of class 1. With a strong F1-score 0.96, the model means that there is a good balance between precision and recall.
#
# The precision on class 2 is also high – 93%, which guaranties its low false positive rate. A recall of 0.92 signals that the significant share of actual cases of class 2 is being uncovered by the model. The F1-score, in this case, is 0.93, i.e., it attests a good overall performance.
#
# This average accuracy score of 93% represents the percentage of correctedly classified instances out of the total being predicted in this model. This, therefore, indicates that the model performed well generally.

# %% [markdown]
# ### Tuned Complement Naive Bayes

# %%
# Defining the pipeline with the Complement Naive Bayes classifier
tuned_nb_clf = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('tuned_nb_clf', ComplementNB())
])

# Defining the parameter grid for hyperparameter tuning
param_grid = {
    'tuned_nb_clf__alpha': [0.1, 0.5, 1.0, 1.5, 2.0],
    'tuned_nb_clf__fit_prior': [True, False]
}

# Creating the GridSearchCV object
tuned_nb_clf_CV = GridSearchCV(tuned_nb_clf, param_grid, cv=5, verbose=1, n_jobs=-1, scoring='accuracy')

# Fitting the model
tuned_nb_clf_CV.fit(X_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", tuned_nb_clf_CV.best_params_)

# Make predictions on the test set using the best model
y_pred = tuned_nb_clf_CV.predict(X_test)

# Perform evaluation 
multiclass_evaluation(y_test, y_pred, X_test, X_train, tuned_nb_clf_CV)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Hyperparameters: {'tuned_nb_clf__alpha': 2.0, 'tuned_nb_clf__fit_prior': True}
# Training Score: 0.86             Test Score:0.78
#
#
# CLASSIFICATION REPORT
# ------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.37      0.46      1364
#            1       0.88      0.79      0.83      7402
#            2       0.68      0.90      0.77      3987
#
#     accuracy                           0.78     12753
#    macro avg       0.72      0.69      0.69     12753
# weighted avg       0.79      0.78      0.77     12753

# %% [markdown]
# After tuning the model, its perfornace has improved on some metrics and dropped on others. A precision of 0.61 for class 0 implies that 61% of the instances predicted as class 0 were correct, recall of 0.37 suggests that the model is not very effective at capturing all instances of class 0 while an F1-score of 0.46 is a measure of balance between precision and recall for class 0.
#
# For class 1, high precision of 0.88 implies the model's ability to correctly identify about 11 out of 12 as class 1 instances and recall of its 0.79 means it captures a considerably good proportion of class 1 instances.
#
# A precision of 0.68 for class 2 means a model has a moderately good ability to predict instances belonged to class 2 accurately, and recall of 0.90 means the model does an excellent job in recognising instances that are belonged to class 2.
#
# The model achieves an overall accuracy of 0.78, correctly predicting class labels for 78% of instances
